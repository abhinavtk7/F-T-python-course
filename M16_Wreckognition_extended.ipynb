# %% [markdown]
# # Wreckognition

# %% [markdown]
# In this section, we will see a few examples of:
# * geographic tools
# * using numpy to manipulate images
# * applying image filters
# * segmentation
# * ML-style clustering

# %% [markdown]
# We will use DAERA's list of protected shipwrecks, hosted by OpenDataNI. For more information, see the [page on their site](https://www.opendatani.gov.uk/dataset/protected-wreck-sites).

# %% [markdown]
# Using these tools, we hope to answer the questions:
#
# > Do wrecks cluster near groups of ports?
#
# and
#
# > Are wrecks more common in deep water or shallow water?

# %% [markdown]
# We may even try to see whether shipwrecks in the 1800s, 1900s or 2000s have different likely locations.

# %% [markdown]
# To begin, we will open up the downloaded dataset using geopandas - this is an extended version of pandas that can attach geographic (or geometric) attributes to each row.

# %% [markdown]
# ## Geopandas

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('protected_wrecks.geojson')

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf
# Out:
#                    Name   Date_lost                              Type  \
# 0                 Ailsa  26/02/1892               Steamship (British)
# 1      (ex HMS) Alastor  11/03/1946  Corvette / Motor yacht (British)
# 2         Albia (poss.)  28/09/1929             Spanish tramp steamer
# 3                Alcedo  ??/01/1892                     Steam coaster
# 4                 Alder        None                              None
# ..                  ...         ...                               ...
# 335             Unknown        None                             Wreck
# 336  Vought F4U Corsair  09/10/1944                          Aircraft
# 337             Unknown        None                             Wreck
# 338             Unknown        None                             Wreck
# 339         HMS Curacao  02/10/1942             C-Class light cruiser
#
#           Cargo   Depth   Position_q  \
# 0       General    1-5m   Reasonable
# 1          None  10-23m     Accurate
# 2    Copper ore     10m  Approximate
# 3          Coal      7m  Approximate
# 4          None     -3m  Approximate
# ..          ...     ...          ...
# 335        None    None     Accurate
# 336        None    None  Approximate
# 337        None    125m     Accurate
# 338        None    139m     Accurate
# 339        None    None         None
#
#                                              Condition             Ref Status  \
# 0            Badly broken up, part of wreck is onshore  UKHO, IRW, CMA   LIVE
# 1    Llargely intact with upright funnel. Wooden de...  UKHO, IRW, CMA   LIVE
# 2                                    5m high, upright.  IRW, UKHO, CMA   LIVE
# 3                           2.5m high, badly broken up        IRW, CMA   LIVE
# 4                                                 None            UKHO   LIFT
# ..                                                 ...             ...    ...
# 335  Concentraion of possible ships timbers protrud...        MFD 2016   None
# 336                                           Wreckage        MFD 2017   None
# 337  The wreck appears to be mostly intact and is a...       AFBI 2017   None
# 338  The wreck appears to be mostly intact and is a...       AFBI 2017   None
# 339                                               None            None   None
#
#                                                Notes  ...   X_Coord  \
# 0                                               None  ... -5.738217
# 1                                               None  ... -5.629383
# 2                                               None  ... -5.741317
# 3                                               None  ... -5.696200
# 4                                 Wreck removed 1938  ... -6.098500
# ..                                               ...  ...       ...
# 335        Observed during foreshore survey 08/11/16  ... -6.208401
# 336    Vought F4U Corsair fighter (serial no. JT693)  ... -7.040083
# 337  Wreck located during 2017 AFBI multibeam survey  ...  0.000000
# 338  Wreck located during 2017 AFBI multibeam survey  ...  0.000000
# 339                                             None  ...  0.000000
#
#        Y_Coord    Updated  Nation   How_lost  \
# 0    54.852500        NaT    None       None
# 1    54.451550        NaT    None       None
# 2    54.949933        NaT    None       None
# 3    54.815483        NaT    None       None
# 4    54.053217        NaT    None       None
# ..         ...        ...     ...        ...
# 335  54.096844 2016-11-08    None       None
# 336  55.072610 2017-02-21    None       None
# 337   0.000000 2017-07-04    None       None
# 338   0.000000 2017-07-04    None       None
# 339   0.000000        NaT    None  Collision
#
#                              Legislatio  \
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
# ..                                  ...
# 335                                None
# 336                                None
# 337                                None
# 338                                None
# 339  Protection Military Remains (1986)
#
#                                             Notes_1           Origin  \
# 0                                              None             None
# 1                                              None             None
# 2                                              None             None
# 3                                              None             None
# 4                                              None             None
# ..                                              ...              ...
# 335                                            None             None
# 336                                            None             None
# 337                                            None             None
# 338                                            None             None
# 339  Designated protected place. Position uncertain  Admiralty owned
#
#              Where_lost                   geometry
# 0                  None   POINT (-5.73822 54.8525)
# 1                  None  POINT (-5.62938 54.45155)
# 2                  None  POINT (-5.74132 54.94993)
# 3                  None   POINT (-5.6962 54.81548)
# 4                  None   POINT (-6.0985 54.05322)
# ..                  ...                        ...
# 335                None   POINT (-6.2084 54.09684)
# 336                None  POINT (-7.04008 55.07261)
# 337                None   POINT (-5.76075 55.0992)
# 338                None  POINT (-5.64846 55.02999)
# 339  60km N of Ireland?  POINT (-6.75512 55.70542)
#
# [340 rows x 24 columns]

# %% [markdown]
# Exploring this data, we see a range of ships - also a few data quality issues in the dates and missing values.
#
# If you have a look at the last, "geometry", column, you will see an entity in WKT (well-known text) format - a computer-readable way of specifying entities.

# %% [markdown]
# We can use matplotlib to take a look.

# %%
# %matplotlib inline

# %%
gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## What? That's not a map

# %% [markdown]
# OK, so that's a scatterplot, which isn't much of a map. We have seen how Python allows us to easily combine different tools and modes of expression. We can use a package called `folium` to make OpenStreetMap / Google Maps style interactive maps.

# %%
import folium

# %% [markdown]
# Naturally, before we show a useful map, we need to decide how to centre it somewhere relevant.

# %% [markdown]
# As it happens, the point associated with each row in geopandas is a `Shapely` geometric entity. It could also be a line, polygon, circle, or a combination of those, for example. We can also ask for the `gdf.geometry`, which is the collection of all the row entities.
#
# Shapely is a geometric package - this means we can do geometric operations on the rows. For example, we can combine all the points into one polka-dot geometric entity - a union operation.

# %%
gdf.geometry.unary_union
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_19860\742342306.py:1: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   gdf.geometry.unary_union
# <MULTIPOINT (-7.315 55.001, -7.309 55.01, -7.309 55.012, -7.294 55.017, -7.2...>

# %% [markdown]
# As a 2d geometric entity, it also has a centroid - a weighted midpoint - which will suffice for us to centre our map.

# %%
middle = gdf.geometry.unary_union.centroid
middle
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_19860\294470364.py:1: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   middle = gdf.geometry.unary_union.centroid
# <POINT (-5.825 54.644)>

# %% [markdown]
# Geometric manipulation is much more useful than mapping - it is critical in many forms of numerical analysis, engineering, design and 3d printing. Explore Shapely's toolkit at your leisure.

# %% [markdown]
# ## Map time

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

def add(wreck):
    pt = wreck.geometry
    folium.Marker(
        [pt.y, pt.x],
        popup=wreck['Name'],
    ).add_to(fmap)
    return wreck

gdf = gdf.apply(add, axis=1)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2eb03e7f04c1cc21dced1a5a5f09e6af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2eb03e7f04c1cc21dced1a5a5f09e6af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2eb03e7f04c1cc21dced1a5a5f09e6af = L.map(
#                 &quot;map_2eb03e7f04c1cc21dced1a5a5f09e6af&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5336f0eae2e0e994f36a7c1ad813325f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5336f0eae2e0e994f36a7c1ad813325f.addTo(map_2eb03e7f04c1cc21dced1a5a5f09e6af);
#
#
#             var marker_8b3a9e8882e94cca56c82c5c43871ee8 = L.marker(
#                 [54.852500423720116, -5.738216765202008],
#                 {}
#             ).addTo(map_2eb03e7f04c1cc21dced1a5a5f09e6af);
#
#
#         var popup_4c05d77323e843175c886fb44dc87bc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c8e51b938154af155a6d29630e284685 = $(`&lt;div id=&quot;html_c8e51b938154af155a6d29630e284685&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_4c05d77323e843175c886fb44dc87bc8.setContent(html_c8e51b938154af155a6d29630e284685);
#
#
#
#         marker_8b3a9e8882e94cca56c82c5c43871ee8.bindPopup(popup_4c05d77323e843175c886fb44dc87bc8)
#         ;
#
#
#
#
#             var marker_ed122f260ca6223624ba69b43d7c8293 = L.marker(
#                 [54.45155042371992, -5.629383430791251],
#                 {}
#             ).addTo(map_2eb03e7f04c1cc21dced1a5a5f09e6af);
#
#
#         var popup_e0a9798b91dde87e9ff548e62ca22629 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d558dc3f370dbe271843a67e731e261c = $(`&lt;div id=&quot;html_d558dc3f370dbe271843a67e731e261c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(ex HMS) Alastor&lt;/div&gt;`)[0];
#                 popup_e0a9798b91dde87e9ff548e62ca22629.setContent(html_d558dc3f370dbe271843a67e731e261c);
#
#
#
#         marker_ed122f260ca6223624ba69b43d7c8293.bindPopup(popup_e0a9798b91dde87e9ff548e62ca22629)
#         ;
#
#
#
#
#             var marker_3b0742b33948a5e7635a13f179f7402c = L.marker(
#                 [54.94993342278837, -5.741317099083887],
#                 {}
#             ).addTo(map_2eb03e7f04c1cc21dced1a5a5f09e6af);
#
#
#         var popup_a6577d430525e6c4886e8c85dbd33518 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5269c69ca67650ea2ce17c083458ac90 = $(`&lt;div id=&quot;html_5269c69ca67650ea2ce17c083458ac90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Albia (poss.)&lt;/div&gt;`)[0];
#                 popup_a6577d430525e6c4886e8c85dbd33518.setContent(html_5269c69ca67650ea2ce17c083458ac90);
#
#
#
#         marker_3b0742b33948a5e7635a13f179f7402c.bindPopup(popup_a6577d430525e6c4886e8c85dbd33518)
#         ;
#
#
#
#
#             var marker_a399e460b7a67261c386e57d61b2e387 = L.marker(
#                 [54.81548342367984, -5.696200098805885],
#                 {}
#             ).addTo(map_2eb03e7f04c1cc21dced1a5a5f09e6af);
#
#
#         var popup_46e5c3627f7b4dae92bdc1cc2e14d216 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_686847f33e7bd89ca80be2798b8a1e76 = $(`&lt;div id=&quot;html_686847f33e7bd89ca80be2798b8a1e76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alcedo&lt;/div&gt;`)[0];
#                 popup_46e5c3627f7b4dae92bdc1cc2e14d216.setContent(html_686847f33e7bd89ca80be2798b8a1e76);
#
#
#
#         marker_a399e460b7a67261c386e57d61b2e387.bindPopup(popup_46e5c3627f7b4dae92bdc1cc2e14d216)
#         ;
#
#
#
#
#             var marker_0c14f19f983b2647b91801da9ccac8a1 = L.marker(
#                 [54.05321709066201, -6.098500100507256],
#                 {}
#             ).addTo(map_2eb03e7f04c1cc21dced1a5a5f09e6af);
#
#
#         var popup_b4e1b741965f4fc017f73bd99d242b2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5972b1c319a2a2b4ea1a0d466cc478c7 = $(`&lt;div id=&quot;html_5972b1c319a2a2b4ea1a0d466cc478c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alder&lt;/div&gt;`)[0];
#                 popup_b4e1b741965f4fc017f73bd99d242b2f.setContent(html_5972b1c319a2a2b4ea1a0d466cc478c7);
#
#
#
#         marker_0c14f19f983b2647b91801da9ccac8a1.bindPopup(popup_b4e1b741965f4fc017f73bd99d242b2f)
#         ;
#
#
#
#
#             var marker_3f05a91c7b4c32e8318867fa709815b5 = L.marker(
#                 [54.02016709118345,

# %% [markdown]
# That should be familiar - as previously, we use the `apply` method on a dataframe to iterate through it (a geopandas geodataframe, but it's essentially the same idea). In each step, we add a marker to the map.
#
# In the first line, we create a map, setting the centre and zoom. For each wreck, we add its coordinates to a new folium `Marker` and call the `add_to` method to append it to the map.

# %% [markdown]
# ## Exercise

# %% [markdown]
# Can you write a function that will take a string entry (it will be the content of the Date_Lost column) and return a string representing the century - '18', '19' or '20' - or None if it is not one of those?

# %% [markdown]
# CLUE: `dateutil` has a parser that can make a best guess at which date a string represents: `dateutil.parser.parse(dt)`

# %%
import dateutil
from datetime import datetime

def get_century(dt):
  try:
    if dt is None:
      dt = ''
    date_object = datetime.strptime(dt, '%d/%m/%Y')
    # Extract the year from the datetime object
    year = date_object.year

    # Calculate the century
    if year % 100 == 0:
        century = year // 100
    else:
        century = (year // 100) + 1

    return str(century)
  except ValueError:
    return None

# %% [markdown]
# Now we can add a `century` column to the data.

# %%
def add(wreck):
    wreck['century'] = get_century(wreck['Date_lost'])
    return wreck

gdf = gdf.apply(add, axis=1)
gdf.head()
# Out:
#                Name   Date_lost                              Type       Cargo  \
# 0             Ailsa  26/02/1892               Steamship (British)     General
# 1  (ex HMS) Alastor  11/03/1946  Corvette / Motor yacht (British)        None
# 2     Albia (poss.)  28/09/1929             Spanish tramp steamer  Copper ore
# 3            Alcedo  ??/01/1892                     Steam coaster        Coal
# 4             Alder        None                              None        None
#
#     Depth   Position_q                                          Condition  \
# 0    1-5m   Reasonable          Badly broken up, part of wreck is onshore
# 1  10-23m     Accurate  Llargely intact with upright funnel. Wooden de...
# 2     10m  Approximate                                  5m high, upright.
# 3      7m  Approximate                         2.5m high, badly broken up
# 4     -3m  Approximate                                               None
#
#               Ref Status               Notes  ...    Y_Coord Updated Nation  \
# 0  UKHO, IRW, CMA   LIVE                None  ...  54.852500     NaT   None
# 1  UKHO, IRW, CMA   LIVE                None  ...  54.451550     NaT   None
# 2  IRW, UKHO, CMA   LIVE                None  ...  54.949933     NaT   None
# 3        IRW, CMA   LIVE                None  ...  54.815483     NaT   None
# 4            UKHO   LIFT  Wreck removed 1938  ...  54.053217     NaT   None
#
#    How_lost  Legislatio  Notes_1 Origin Where_lost                   geometry  \
# 0      None        None     None   None       None   POINT (-5.73822 54.8525)
# 1      None        None     None   None       None  POINT (-5.62938 54.45155)
# 2      None        None     None   None       None  POINT (-5.74132 54.94993)
# 3      None        None     None   None       None   POINT (-5.6962 54.81548)
# 4      None        None     None   None       None   POINT (-6.0985 54.05322)
#
#   century
# 0      19
# 1      20
# 2      20
# 3    None
# 4    None
#
# [5 rows x 25 columns]

# %%
type(gdf['century'][0])
# Out:
# str

# %% [markdown]
# Many points don't have a century, but lets ignore that for now.

# %% [markdown]
# Folium also lets us group markers. This is much more useful. Here we create several `FeatureGroup` map layers and them to the map. We then add markers directly to each century's FeatureGroup with coloured icons. At the end, we add a layer control, so you can turn each group on and off.

# %%
type(gdf['century'][0])
# Out:
# str

# %%
middle.y
# Out:
# 54.64427445282978

# %%
from folium import FeatureGroup, LayerControl

fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

centuries = {
    '18': 'red',
    '19': 'green',
    '20': 'blue'
}
clusters = {}

for century, colour in centuries.items():
    clusters[century] = FeatureGroup(name=century)
    clusters[century].add_to(fmap)

def add(wreck):
    wreck['century'] = get_century(wreck['Date_lost'])

    pt = wreck.geometry
    if wreck['century'] in centuries:
        colour = centuries[wreck['century']]
        folium.Marker(
            [pt.y, pt.x],
            popup=wreck['Name'],
            icon=folium.Icon(color=colour)
        ).add_to(clusters[wreck['century']])

    return wreck

# %%
gdf = gdf.apply(add, axis=1)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79be1ed189994d86b2bf31dc08a521ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79be1ed189994d86b2bf31dc08a521ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79be1ed189994d86b2bf31dc08a521ce = L.map(
#                 &quot;map_79be1ed189994d86b2bf31dc08a521ce&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_adc69b600ec9f2ea0d28afdfa560d0d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_adc69b600ec9f2ea0d28afdfa560d0d6.addTo(map_79be1ed189994d86b2bf31dc08a521ce);
#
#
#             var feature_group_854e5a6ce57f5a5eba8f84cfad37a949 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_ea593f60a6b483c515d9c09c1257cad5 = L.marker(
#                 [54.952095592630954, -5.744053278344665],
#                 {}
#             ).addTo(feature_group_854e5a6ce57f5a5eba8f84cfad37a949);
#
#
#             var icon_e799384e7f8a17238c7e5f3804e0573a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea593f60a6b483c515d9c09c1257cad5.setIcon(icon_e799384e7f8a17238c7e5f3804e0573a);
#
#
#         var popup_0bd07f47889458baa9110829e15498b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6f9e1b2b419c1b7c3b110d4d05325411 = $(`&lt;div id=&quot;html_6f9e1b2b419c1b7c3b110d4d05325411&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Unknown&lt;/div&gt;`)[0];
#                 popup_0bd07f47889458baa9110829e15498b1.setContent(html_6f9e1b2b419c1b7c3b110d4d05325411);
#
#
#
#         marker_ea593f60a6b483c515d9c09c1257cad5.bindPopup(popup_0bd07f47889458baa9110829e15498b1)
#         ;
#
#
#
#
#             var marker_cda737bf30be942af64c8e274e5ccadf = L.marker(
#                 [55.22225365268374, -6.629235293324471],
#                 {}
#             ).addTo(feature_group_854e5a6ce57f5a5eba8f84cfad37a949);
#
#
#             var icon_8f212fa93342665d6871f06941499b56 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_cda737bf30be942af64c8e274e5ccadf.setIcon(icon_8f212fa93342665d6871f06941499b56);
#
#
#         var popup_a381f1a9ef770582505bcc9261a163be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_87938e0c33b11c9a98fe209f6dcabd5e = $(`&lt;div id=&quot;html_87938e0c33b11c9a98fe209f6dcabd5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;N/A&lt;/div&gt;`)[0];
#                 popup_a381f1a9ef770582505bcc9261a163be.setContent(html_87938e0c33b11c9a98fe209f6dcabd5e);
#
#
#
#         marker_cda737bf30be942af64c8e274e5ccadf.bindPopup(popup_a381f1a9ef770582505bcc9261a163be)
#         ;
#
#
#
#
#             feature_group_854e5a6ce57f5a5eba8f84cfad37a949.addTo(map_79be1ed189994d86b2bf31dc08a521ce);
#
#
#             var feature_group_aee9419b7698ef9c8374a105446a0f08 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_ff2e17f7684abef4f4433e2d0d2c3b13 = L.marker(
#                 [54.852500423720116, -5.738216765202008],
#                 {}
#             ).addTo(feature_group_aee9419b7698ef9c8374a105446a0f08);
#
#
#             var icon_17c9181142d0ce0e101673358d032f75 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ff2e17f7684abef4f4433e2d0d2c3b13.setIcon(icon_17c9181142d0ce0e101673358d032f75);
#
#
#         var popup_bd56a0dd546eee5968cb1af787efff7f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0ffff47ddacb2ec88b1b569169a93d86 = $(`&lt;div id=&quot;html_0ffff47ddacb2ec88b1b569169a93d86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_bd56a0dd546eee5968cb1af787efff7f.setContent(html_0ffff47ddacb2ec88b1b569169a93d86);
#
#
#
#         marker_ff2e17f7684abef4f4433e2d0d2c3b13.bindPopup(popup_bd56a0dd546eee5968cb1af787efff7f)
#         ;

# %% [markdown]
# ## Changing of the Seasons

# %% [markdown]
# Let's pick a century. 1900's, for example.

# %%
century = '19' # if you want to try a different century, come back here, change this and run the cells below

# %%
# kmeans isn't the best option, as lat-long is not linear and we are guessing cluster numbers,
# but this illustrates how it can work
from sklearn.cluster import KMeans
import numpy as np

gdf['label'] = -1
kdf = gdf[gdf['century'] == century]
locations = np.array([[w.geometry.y, w.geometry.x] for n, w in kdf.iterrows()])
locations
# Out:
# array([[54.85250042, -5.73821677],
#        [54.44620042, -5.37560009],
#        [54.85368342, -5.7697831 ],
#        [54.78753342, -5.6885831 ],
#        [54.67150913, -5.77305105],
#        [55.27499802, -6.2025764 ],
#        [54.33125416, -5.49898497],
#        [54.06666709, -5.95833343],
#        [54.85222589, -5.7908119 ],
#        [55.29536126, -6.28592233],
#        [54.43380042, -5.39493309],
#        [55.26420184, -6.19813141],
#        [54.58333342, -5.4833331 ],
#        [55.27752641, -6.17896666],
#        [54.28088376, -5.52776676],
#        [54.53983376, -5.45181565],
#        [54.95288342, -5.7302501 ],
#        [54.38882984, -5.56496278],
#        [55.19286713, -6.70915706],
#        [54.88200042, -5.75271677],
#        [54.95286742, -5.7302501 ],
#        [54.69685785, -5.5302748 ],
#        [55.14917541, -6.02282832],
#        [55.29163042, -6.2468801 ],
#        [55.20695042, -6.60878344],
#        [53.95381709, -5.92096677],
#        [55.16916709, -6.75961678],
#        [54.88255042, -5.75188343]])

# %% [markdown]
# Now we set up our k-means algorithm - this involves choosing an expected number of clusters - and fit it to our locations list. It generates a numpy array of labels, one entry for each location representing its cluster.

# %%
kmeans = KMeans(n_clusters=6).fit(locations)
kmeans.labels_
# Out:
# C:\Users\abhin\Downloads\anaconda3-2023\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\abhin\Downloads\anaconda3-2023\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# array([4, 1, 4, 4, 4, 0, 1, 5, 4, 0, 1, 0, 3, 0, 1, 3, 4, 1, 2, 4, 4, 3,
#        0, 0, 2, 5, 2, 4])

# %% [markdown]
# We can then add these in the specific entries in the dataframe.

# %%
for n, label in enumerate(kmeans.labels_):
    gdf.loc[kdf.index[n], 'label'] = label

kdf = gdf[gdf['century'] == century]
kdf.loc[:, 'label'].head()
# Out:
# 0     4
# 10    1
# 18    4
# 22    4
# 29    4
# Name: label, dtype: int64

# %% [markdown]
# How does this look on the original map?

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

colours = ['red', 'green', 'blue', 'orange', 'pink', 'gray']
clusters = {}

for label, colour in enumerate(colours):
    clusters[label] = FeatureGroup(name="Cluster %d" % label)
    clusters[label].add_to(fmap)

def add(wreck):
    pt = wreck.geometry

    colour = colours[wreck['label']]
    folium.Marker(
        [pt.y, pt.x],
        popup=wreck['Name'],
        icon=folium.Icon(color=colour)
    ).add_to(clusters[wreck['label']])

    return wreck

kdf = kdf.apply(add, axis=1)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36b7714f055e429db9ee650ed212f8fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36b7714f055e429db9ee650ed212f8fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36b7714f055e429db9ee650ed212f8fe = L.map(
#                 &quot;map_36b7714f055e429db9ee650ed212f8fe&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5563e7d0da62f29aedc89a100ed14e24 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5563e7d0da62f29aedc89a100ed14e24.addTo(map_36b7714f055e429db9ee650ed212f8fe);
#
#
#             var feature_group_a7c3285040f2742bf32bc64084d0d197 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_964ff8c58e115a859468f6b420cc6d4b = L.marker(
#                 [55.27499801502037, -6.202576404675912],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_b118e167f84c9a67da500f372565c2bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_964ff8c58e115a859468f6b420cc6d4b.setIcon(icon_b118e167f84c9a67da500f372565c2bd);
#
#
#         var popup_b36dfefd48bd01a6129e47e0602229d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53a4a6be66cf94dd00fc04c5d345fdcd = $(`&lt;div id=&quot;html_53a4a6be66cf94dd00fc04c5d345fdcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumberland&lt;/div&gt;`)[0];
#                 popup_b36dfefd48bd01a6129e47e0602229d0.setContent(html_53a4a6be66cf94dd00fc04c5d345fdcd);
#
#
#
#         marker_964ff8c58e115a859468f6b420cc6d4b.bindPopup(popup_b36dfefd48bd01a6129e47e0602229d0)
#         ;
#
#
#
#
#             var marker_e798cfb1d0cddc371a01a1e6df9991f4 = L.marker(
#                 [55.29536125518683, -6.285922327048246],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_bb0447e1dec79ebb900278b871d85208 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e798cfb1d0cddc371a01a1e6df9991f4.setIcon(icon_bb0447e1dec79ebb900278b871d85208);
#
#
#         var popup_a274ccc8f9524021b11167a7f68083cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48fc66f3b4196648c08a8607371fc896 = $(`&lt;div id=&quot;html_48fc66f3b4196648c08a8607371fc896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Girvan&lt;/div&gt;`)[0];
#                 popup_a274ccc8f9524021b11167a7f68083cd.setContent(html_48fc66f3b4196648c08a8607371fc896);
#
#
#
#         marker_e798cfb1d0cddc371a01a1e6df9991f4.bindPopup(popup_a274ccc8f9524021b11167a7f68083cd)
#         ;
#
#
#
#
#             var marker_ff0fabce20524ed30ef3b8320cbdd1a5 = L.marker(
#                 [55.2642018427371, -6.198131405570238],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_3dbfba2628d738e740e4940254117c3b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ff0fabce20524ed30ef3b8320cbdd1a5.setIcon(icon_3dbfba2628d738e740e4940254117c3b);
#
#
#         var popup_a4d09cccbb95fe9cd5b0e76d38cd14a5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4865d019d1e46083c48044a760135003 = $(`&lt;div id=&quot;html_4865d019d1e46083c48044a760135003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Her Majesty&lt;/div&gt;`)[0];
#                 popup_a4d09cccbb95fe9cd5b0e76d38cd14a5.setContent(html_4865d019d1e46083c48044a760135003);
#
#
#
#         marker_ff0fabce20524ed30ef3b8320cbdd1a5.bindPopup(popup_a4d09cccbb95fe9cd5b0e76d38cd14a5)
#         ;
#
#
#
#
#             var marker_14054d1a4c717cada8efb0976e0d07cb = L.marker(
#                 [55.277526408606185, -6.178966659279183],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);

# %% [markdown]
# # Quiz
#
# * Which of NI's main harbours match to which clusters?
# * How does it change with the number of labels you use?
# * How does it change with the century?

# %% [markdown]
# # Looks deep

# %% [markdown]
# Next question: is there a correlation between depth and number of shipwrecks?
#
# Rather than using the official bathymetry data, we will try and guess depth from shades of blue in satellite images. There's a few issues with our approach here - such as the resolution of the images, the processing that's already been done to them, the fact that colour isn't necessarily a good proxy for depth - but it will demonstrate how we can use image manipulation to back up other analysis.

# %% [markdown]
# First, we show the Sentinel-2 open satellite data as a map layer.

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

attr = """
<i>
<a class="a-light" xmlns:dct="http://purl.org/dc/terms/"
      href="https://s2maps.eu" property="dct:title">
  Sentinel-2 cloudless - https://s2maps.eu
</a> by
<a class="a-light" xmlns:cc="http://creativecommons.org/ns#"
      href="https://eox.at" property="cc:attributionName"
      rel="cc:attributionURL">
  EOX IT Services GmbH
</a><br/>
(Contains modified Copernicus Sentinel data 2016 &amp; 2017)</i>
"""
sentinel = folium.WmsTileLayer(
    url='https://tiles.maps.eox.at/wms',
    name='s2maps.eu',
    fmt='image/png',
    attr=attr,
    layers='s2cloudless_3857'
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5186d6ba20355e70121f54aaf07b3757 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5186d6ba20355e70121f54aaf07b3757&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5186d6ba20355e70121f54aaf07b3757 = L.map(
#                 &quot;map_5186d6ba20355e70121f54aaf07b3757&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b7c3e8dc6be2735d60314afcca7e00dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b7c3e8dc6be2735d60314afcca7e00dc.addTo(map_5186d6ba20355e70121f54aaf07b3757);
#
#
#             var macro_element_e37effd8a658bf0e2d373559b7eef0cc = L.tileLayer.wms(
#                 &quot;https://tiles.maps.eox.at/wms&quot;,
#                 {&quot;attribution&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;s2cloudless_3857&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: false, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_e37effd8a658bf0e2d373559b7eef0cc.addTo(map_5186d6ba20355e70121f54aaf07b3757);
#
#
#             var feature_group_a7c3285040f2742bf32bc64084d0d197 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_964ff8c58e115a859468f6b420cc6d4b = L.marker(
#                 [55.27499801502037, -6.202576404675912],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_b118e167f84c9a67da500f372565c2bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_964ff8c58e115a859468f6b420cc6d4b.setIcon(icon_b118e167f84c9a67da500f372565c2bd);
#
#
#         var popup_b36dfefd48bd01a6129e47e0602229d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53a4a6be66cf94dd00fc04c5d345fdcd = $(`&lt;div id=&quot;html_53a4a6be66cf94dd00fc04c5d345fdcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumberland&lt;/div&gt;`)[0];
#                 popup_b36dfefd48bd01a6129e47e0602229d0.setContent(html_53a4a6be66cf94dd00fc04c5d345fdcd);
#
#
#
#         marker_964ff8c58e115a859468f6b420cc6d4b.bindPopup(popup_b36dfefd48bd01a6129e47e0602229d0)
#         ;
#
#
#
#
#             var marker_e798cfb1d0cddc371a01a1e6df9991f4 = L.marker(
#                 [55.29536125518683, -6.285922327048246],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_bb0447e1dec79ebb900278b871d85208 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e798cfb1d0cddc371a01a1e6df9991f4.setIcon(icon_bb0447e1dec79ebb900278b871d85208);
#
#
#         var popup_a274ccc8f9524021b11167a7f68083cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48fc66f3b4196648c08a8607371fc896 = $(`&lt;div id=&quot;html_48fc66f3b4196648c08a8607371fc896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Girvan&lt;/div&gt;`)[0];
#                 popup_a274ccc8f9524021b11167a7f68083cd.setContent(html_48fc66f3b4196648c08a8607371fc896);
#
#
#
#         marker_e798cfb1d0cddc371a01a1e6df9991f4.bindPopup(popup_a274ccc8f9524021b11167a7f68083cd)
#         ;
#
#
#
#
#             var marker_ff0fabce20524ed30ef3b8320cbdd1a5 = L.marker(
#                 [55.2642018427371, -6.198131405570238],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_3dbfba2628d738e740e4940254117c3b = L.AwesomeMarkers.icon(
#                 {&quot;extr

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

attr = """
<i>
<a class="a-light" xmlns:dct="http://purl.org/dc/terms/"
      href="https://s2maps.eu" property="dct:title">
  Sentinel-2 cloudless - https://s2maps.eu
</a> by
<a class="a-light" xmlns:cc="http://creativecommons.org/ns#"
      href="https://eox.at" property="cc:attributionName"
      rel="cc:attributionURL">
  EOX IT Services GmbH
</a><br/>
(Contains modified Copernicus Sentinel data 2016 &amp; 2017)</i>
"""
sentinel = folium.WmsTileLayer(
    url='https://tiles.maps.eox.at/wms',
    name='s2maps.eu',
    fmt='image/png',
    attr=attr,
    layers='s2cloudless_3857'
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e698c32939193ddffd852cce73cf9ce8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e698c32939193ddffd852cce73cf9ce8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e698c32939193ddffd852cce73cf9ce8 = L.map(
#                 &quot;map_e698c32939193ddffd852cce73cf9ce8&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_44982c4188b8737c4627f47a76f18708 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_44982c4188b8737c4627f47a76f18708.addTo(map_e698c32939193ddffd852cce73cf9ce8);
#
#
#             var macro_element_ab936909e87fc563666d2b2b1d3ac97e = L.tileLayer.wms(
#                 &quot;https://tiles.maps.eox.at/wms&quot;,
#                 {&quot;attribution&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;s2cloudless_3857&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: false, &quot;version&quot;: &quot;1.1.1&quot;}
#             );
#
#
#             macro_element_ab936909e87fc563666d2b2b1d3ac97e.addTo(map_e698c32939193ddffd852cce73cf9ce8);
#
#
#             var feature_group_a7c3285040f2742bf32bc64084d0d197 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_964ff8c58e115a859468f6b420cc6d4b = L.marker(
#                 [55.27499801502037, -6.202576404675912],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_b118e167f84c9a67da500f372565c2bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_964ff8c58e115a859468f6b420cc6d4b.setIcon(icon_b118e167f84c9a67da500f372565c2bd);
#
#
#         var popup_b36dfefd48bd01a6129e47e0602229d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53a4a6be66cf94dd00fc04c5d345fdcd = $(`&lt;div id=&quot;html_53a4a6be66cf94dd00fc04c5d345fdcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumberland&lt;/div&gt;`)[0];
#                 popup_b36dfefd48bd01a6129e47e0602229d0.setContent(html_53a4a6be66cf94dd00fc04c5d345fdcd);
#
#
#
#         marker_964ff8c58e115a859468f6b420cc6d4b.bindPopup(popup_b36dfefd48bd01a6129e47e0602229d0)
#         ;
#
#
#
#
#             var marker_e798cfb1d0cddc371a01a1e6df9991f4 = L.marker(
#                 [55.29536125518683, -6.285922327048246],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_bb0447e1dec79ebb900278b871d85208 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e798cfb1d0cddc371a01a1e6df9991f4.setIcon(icon_bb0447e1dec79ebb900278b871d85208);
#
#
#         var popup_a274ccc8f9524021b11167a7f68083cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48fc66f3b4196648c08a8607371fc896 = $(`&lt;div id=&quot;html_48fc66f3b4196648c08a8607371fc896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Girvan&lt;/div&gt;`)[0];
#                 popup_a274ccc8f9524021b11167a7f68083cd.setContent(html_48fc66f3b4196648c08a8607371fc896);
#
#
#
#         marker_e798cfb1d0cddc371a01a1e6df9991f4.bindPopup(popup_a274ccc8f9524021b11167a7f68083cd)
#         ;
#
#
#
#
#             var marker_ff0fabce20524ed30ef3b8320cbdd1a5 = L.marker(
#                 [55.2642018427371, -6.198131405570238],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_3dbfba2628d738e740e4940254117c3b = L.AwesomeMarkers.icon(
#                 {&quot;extr

# %% [markdown]
# Rather than examining _all_ this data - I have chopped out a tile for our convenience. An image we can manipulate...

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

tile = folium.raster_layers.ImageOverlay(
    url='https://tiles.maps.eox.at/wms',
    name='coast',
    image='coast.jpg',
    fmt='jpg',
    bounds=[[53.81683262680313, -6.78096405771856],[55.45928868149063, -5.14400116709356]],
    attr=attr,
    opacity=0.6,
    zindex=1
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fe022b180bcdb5390fceb60a4f9bc12 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fe022b180bcdb5390fceb60a4f9bc12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fe022b180bcdb5390fceb60a4f9bc12 = L.map(
#                 &quot;map_7fe022b180bcdb5390fceb60a4f9bc12&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb8a34829d45077b2f73e1e1fad42d12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_bb8a34829d45077b2f73e1e1fad42d12.addTo(map_7fe022b180bcdb5390fceb60a4f9bc12);
#
#
#             var image_overlay_e374f8662ce1f4e3ff44b4ce2264a94b = L.imageOverlay(
#                 &quot;data:image/jpg;base64,...&quot;,
#                 [[53.81683262680313, -6.78096405771856], [55.45928868149063, -5.14400116709356]],
#                 {&quot;attr&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;, &quot;fmt&quot;: &quot;jpg&quot;, &quot;opacity&quot;: 0.6, &quot;url&quot;: &quot;https://tiles.maps.eox.at/wms&quot;, &quot;zindex&quot;: 1}
#             );
#
#
#             image_overlay_e374f8662ce1f4e3ff44b4ce2264a94b.addTo(map_7fe022b180bcdb5390fceb60a4f9bc12);
#
#
#             var feature_group_a7c3285040f2742bf32bc64084d0d197 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_964ff8c58e115a859468f6b420cc6d4b = L.marker(
#                 [55.27499801502037, -6.202576404675912],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_b118e167f84c9a67da500f372565c2bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_964ff8c58e115a859468f6b420cc6d4b.setIcon(icon_b118e167f84c9a67da500f372565c2bd);
#
#
#         var popup_b36dfefd48bd01a6129e47e0602229d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53a4a6be66cf94dd00fc04c5d345fdcd = $(`&lt;div id=&quot;html_53a4a6be66cf94dd00fc04c5d345fdcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumberland&lt;/div&gt;`)[0];
#                 popup_b36dfefd48bd01a6129e47e0602229d0.setContent(html_53a4a6be66cf94dd00fc04c5d345fdcd);
#
#
#
#         marker_964ff8c58e115a859468f6b420cc6d4b.bindPopup(popup_b36dfefd48bd01a6129e47e0602229d0)
#         ;
#
#
#
#
#             var marker_e798cfb1d0cddc371a01a1e6df9991f4 = L.marker(
#                 [55.29536125518683, -6.285922327048246],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_bb0447e1dec79ebb900278b871d85208 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e798cfb1d0cddc371a01a1e6df9991f4.setIcon(icon_bb0447e1dec79ebb900278b871d85208);
#
#
#         var popup_a274ccc8f9524021b11167a7f68083cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48fc66f3b4196648c08a8607371fc896 = $(`&lt;div id=&quot;html_48fc66f3b4196648c08a8607371fc896&quot; style=&quot;width: 100.0%;

# %% [markdown]
# Now, how do we actually use a picture like data? scikit-image (skimage) has a lot of image manipulation tools - these can be coupled with scikit-learn in certain contexts to do image-based machine learning, so this is a brief intro.

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
# %matplotlib inline

# %%
coast = skimage.io.imread('coast.jpg')
plt.imshow(coast)

# %% [markdown]
# We have actually imported this image as a numpy array. In fact, this is actually plotting using the same technique as our Inflammation numpy tutorial - it's a graph of cells, where each cell has colour values. Pixels you might say...

# %%
coast[0, 0, :]
# Out:
# array([14, 33, 48], dtype=uint8)

# %% [markdown]
# First, we soften some of the noise using a Gaussian blur.

# %%
from skimage import filters

smooth = filters.gaussian(coast, sigma=10)
plt.imshow(smooth)
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_19860\40288959.py:3: FutureWarning: Automatic detection of the color channel was deprecated in v0.19, and `channel_axis=None` will be the new default in v0.21. Set `channel_axis=-1` explicitly to silence this warning.
#   smooth = filters.gaussian(coast, sigma=10)

# %% [markdown]
# As this is a 3d matrix, as far as numpy is concerned, we can extract a single colour channel using a slice. Here is the green one (think RGB - G has index 1).

# %%
plt.imshow(smooth[:,:,1])

# %% [markdown]
# A simple, coarse way to trim all the non-sea (land, as it's known) is to pick everything that is more than a little green. Here we set anything with more than 0.2 in the green column to black.

# %%
smooth[smooth[:,:,1] > 0.2] = [0, 0, 0]
plt.imshow(smooth)

# %% [markdown]
# Next, we go one step further, by selecting _just_ the blue channel and trimming (setting to -1) everything that is outside of an emperical or heuristic (i.e. guessed or made up) window.

# %%
sea = smooth[:,:,2].copy()
sea[(sea < 0.1) | (sea > 0.25)] = -1
plt.imshow(sea)

# %% [markdown]
# OK, so we have some sea now - we know where it is. Now lets split it into layers of deep and shallow. To do this, we use a basic image segmentation technique, which is no more than numpy's `histogram` function. This puts all of our pixels into labeled "bins" (or layers, in our 2d image case).

# %%
# This number is our own choice of sea-depth layers
bins = 5

# We split up the sea into a set of bins
hist, bin_edges = np.histogram(
    sea,
    bins=bins,
    range=(sea[sea > 0].min(), sea.max())
)

# And create a new array called layers that matches each pixel to a depth layer: shallow...deep
last_edge = bin_edges[0]
layers = np.zeros(sea.shape, dtype=int) - 1
for n, next_edge in enumerate(bin_edges[1:]):
    layers[(sea > last_edge) & (sea <= next_edge)] = n
    last_edge = next_edge
plt.imshow(layers)

# %% [markdown]
# Now we can see the variety of layers - with as many colours as our `bins` variable.

# %% [markdown]
# As an aside for later - let's calculate what fraction of the visible sea each layer takes up.

# %%
segment_frequencies = np.bincount(layers[layers >= 0].flatten())
nonzero_pixels = sum(segment_frequencies)
segment_fraction = segment_frequencies / nonzero_pixels
segment_fraction
# Out:
# array([0.1091253 , 0.42614025, 0.32343668, 0.10812775, 0.03317001])

# %% [markdown]
# ## Back to charts
#
# Does this match up with our map?

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

layer_bounds = [[53.81683262680313, -6.78096405771856],[55.45928868149063, -5.14400116709356]]

tile = folium.raster_layers.ImageOverlay(
    name='coast',
    image=layers,
    bounds=layer_bounds,
    attr=attr,
    opacity=0.6,
    zindex=1
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_064b0d770ebfb6a4404d27175edf092f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_064b0d770ebfb6a4404d27175edf092f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_064b0d770ebfb6a4404d27175edf092f = L.map(
#                 &quot;map_064b0d770ebfb6a4404d27175edf092f&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dde892b53fe4bcaedbe8dc1fd1c5bb90 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_dde892b53fe4bcaedbe8dc1fd1c5bb90.addTo(map_064b0d770ebfb6a4404d27175edf092f);
#
#
#             var image_overlay_263877e99dea18ff4831f955024c7ff6 = L.imageOverlay(
#                 &quot;data:image/png;base64,...&quot;,
#                 [[53.81683262680313, -6.78096405771856], [55.45928868149063, -5.14400116709356]],
#                 {&quot;attr&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;, &quot;opacity&quot;: 0.6, &quot;zindex&quot;: 1}
#             );
#
#
#             image_overlay_263877e99dea18ff4831f955024c7ff6.addTo(map_064b0d770ebfb6a4404d27175edf092f);
#
#
#             var feature_group_a7c3285040f2742bf32bc64084d0d197 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_964ff8c58e115a859468f6b420cc6d4b = L.marker(
#                 [55.27499801502037, -6.202576404675912],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_b118e167f84c9a67da500f372565c2bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_964ff8c58e115a859468f6b420cc6d4b.setIcon(icon_b118e167f84c9a67da500f372565c2bd);
#
#
#         var popup_b36dfefd48bd01a6129e47e0602229d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53a4a6be66cf94dd00fc04c5d345fdcd = $(`&lt;div id=&quot;html_53a4a6be66cf94dd00fc04c5d345fdcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumberland&lt;/div&gt;`)[0];
#                 popup_b36dfefd48bd01a6129e47e0602229d0.setContent(html_53a4a6be66cf94dd00fc04c5d345fdcd);
#
#
#
#         marker_964ff8c58e115a859468f6b420cc6d4b.bindPopup(popup_b36dfefd48bd01a6129e47e0602229d0)
#         ;
#
#
#
#
#             var marker_e798cfb1d0cddc371a01a1e6df9991f4 = L.marker(
#                 [55.29536125518683, -6.285922327048246],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_bb0447e1dec79ebb900278b871d85208 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e798cfb1d0cddc371a01a1e6df9991f4.setIcon(icon_bb0447e1dec79ebb900278b871d85208);
#
#
#         var popup_a274ccc8f9524021b11167a7f68083cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48fc66f3b4196648c08a8607371fc896 = $(`&lt;div id=&quot;html_48fc66f3b4196648c08a8607371fc896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Girvan&lt;/div&gt;`)[0];
#                 popup_a274ccc8f9524021b11167

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

layer_bounds = [[53.81683262680313, -6.78096405771856],[55.45928868149063, -5.14400116709356]]

tile = folium.raster_layers.ImageOverlay(
    name='coast',
    image=layers,
    bounds=layer_bounds,
    attr=attr,
    opacity=0.6,
    zindex=1
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eaa8209947e6af34b3de57d2e45544f7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eaa8209947e6af34b3de57d2e45544f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eaa8209947e6af34b3de57d2e45544f7 = L.map(
#                 &quot;map_eaa8209947e6af34b3de57d2e45544f7&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7cc041c3c0f3efd4f0bcc4ebbcee0b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e7cc041c3c0f3efd4f0bcc4ebbcee0b9.addTo(map_eaa8209947e6af34b3de57d2e45544f7);
#
#
#             var image_overlay_6705f1dd96c85901396904f64fddb582 = L.imageOverlay(
#                 &quot;data:image/png;base64,...&quot;,
#                 [[53.81683262680313, -6.78096405771856], [55.45928868149063, -5.14400116709356]],
#                 {&quot;attr&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;, &quot;opacity&quot;: 0.6, &quot;zindex&quot;: 1}
#             );
#
#
#             image_overlay_6705f1dd96c85901396904f64fddb582.addTo(map_eaa8209947e6af34b3de57d2e45544f7);
#
#
#             var feature_group_a7c3285040f2742bf32bc64084d0d197 = L.featureGroup(
#                 {}
#             );
#
#
#             var marker_964ff8c58e115a859468f6b420cc6d4b = L.marker(
#                 [55.27499801502037, -6.202576404675912],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_b118e167f84c9a67da500f372565c2bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_964ff8c58e115a859468f6b420cc6d4b.setIcon(icon_b118e167f84c9a67da500f372565c2bd);
#
#
#         var popup_b36dfefd48bd01a6129e47e0602229d0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_53a4a6be66cf94dd00fc04c5d345fdcd = $(`&lt;div id=&quot;html_53a4a6be66cf94dd00fc04c5d345fdcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumberland&lt;/div&gt;`)[0];
#                 popup_b36dfefd48bd01a6129e47e0602229d0.setContent(html_53a4a6be66cf94dd00fc04c5d345fdcd);
#
#
#
#         marker_964ff8c58e115a859468f6b420cc6d4b.bindPopup(popup_b36dfefd48bd01a6129e47e0602229d0)
#         ;
#
#
#
#
#             var marker_e798cfb1d0cddc371a01a1e6df9991f4 = L.marker(
#                 [55.29536125518683, -6.285922327048246],
#                 {}
#             ).addTo(feature_group_a7c3285040f2742bf32bc64084d0d197);
#
#
#             var icon_bb0447e1dec79ebb900278b871d85208 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e798cfb1d0cddc371a01a1e6df9991f4.setIcon(icon_bb0447e1dec79ebb900278b871d85208);
#
#
#         var popup_a274ccc8f9524021b11167a7f68083cd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_48fc66f3b4196648c08a8607371fc896 = $(`&lt;div id=&quot;html_48fc66f3b4196648c08a8607371fc896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Girvan&lt;/div&gt;`)[0];
#                 popup_a274ccc8f9524021b11167

# %% [markdown]
# Close enough, given all the approximations. Next...
#
# ## Labelling our wrecks
#
# We need to create a function that we can pass a wreck to, and it will give its corresponding layer.
#
# We have a couple of convenient tools in scipy and numpy:
# * linspace : this creates an array linearly spread from one limit to another
# * meshgrid : this turns a set of horizontal and vertical axis ticks into a list of all the points in the corresponding grid
# * inter2p : this takes a series of axis ticks and function values at every grid point, and gives a callable function taking any coordinate whatsoever and returning the linearly-interpolated function value

# %%
import scipy

layer_x = np.linspace(layer_bounds[0][1], layer_bounds[1][1], len(layers[0]))
layer_y = np.linspace(layer_bounds[1][0], layer_bounds[0][0], len(layers))
layers_flat = layers.copy().flatten()
segment = scipy.interpolate.interp2d(layer_x, layer_y, layers)
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_19860\1295895320.py:6: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   segment = scipy.interpolate.interp2d(layer_x, layer_y, layers)

# %% [markdown]
# We can plot this interpolated function to see what it looks like in 3D.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig = plt.figure(figsize=(10, 10))
# ax = fig.gca(projection='3d')
ax = fig.add_subplot(projection='3d')

ax.set_zlim(-10, 10)
ax.view_init(60, -90)

X, Y = np.meshgrid(layer_x, layer_y)
surf = ax.plot_surface(X, Y, segment(layer_x, layer_y), cmap=cm.coolwarm)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_19860\1722792044.py:12: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   surf = ax.plot_surface(X, Y, segment(layer_x, layer_y), cmap=cm.coolwarm)

# %% [markdown]
# Finally, to use our interpolated labelling function, we turn back to our old dataframe method, `apply`.

# %%
def point_to_segment(wreck):
    interp = segment(wreck.geometry.x, wreck.geometry.y)
    wreck['segment'] = int(round(interp[0]))
    return wreck
gdf = gdf.apply(point_to_segment, axis=1)
# Out:
# C:\Users\abhin\AppData\Local\Temp\ipykernel_19860\2598215986.py:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)

# %% [markdown]
# ## Displaying this detail

# %% [markdown]
# Lets work out which segments we actually have wrecks in (we don't want to add more layers than necessary)

# %%
segments_active = set(gdf.loc[:, 'segment']) - {-1}
segments_active
# Out:
# {0, 1, 2, 3, 4}

# %% [markdown]
# Now lets create a copy of our dataframe for further manipulation.

# %%
# ldf = gdf.copy()
ldf = gdf[gdf['century'] == '19'].copy()

# %% [markdown]
# Much as above, we can run through our wrecks, but we use a handy colourmap library to give us shades indicating our depth layer.

# %%
import branca.colormap as cm

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

mid = min(segments_active) + (max(segments_active) - min(segments_active)) / 2
colormap = cm.LinearColormap(
    ['red', 'yellow', 'green'],
    index=[min(segments_active), mid, max(segments_active)]
)

def add(wreck):
    pt = wreck.geometry

    if wreck['segment'] > -1:
        colour = colormap(wreck['segment'])
        folium.CircleMarker(
            [pt.y, pt.x],
            popup=wreck['Name'],
            fill_color=colour,
            color=colour
        ).add_to(fmap)

    return wreck

ldf = ldf.apply(add, axis=1)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a929a5ac99c609c00c98279d743a9784 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a929a5ac99c609c00c98279d743a9784&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a929a5ac99c609c00c98279d743a9784 = L.map(
#                 &quot;map_a929a5ac99c609c00c98279d743a9784&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c2731ea396e12b9c73f95e023ab8cc0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2c2731ea396e12b9c73f95e023ab8cc0.addTo(map_a929a5ac99c609c00c98279d743a9784);
#
#
#             var circle_marker_7e24497574012939c1d78ddbbaaf2683 = L.circleMarker(
#                 [54.44620042451414, -5.375600094540772],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff7f00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff7f00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a929a5ac99c609c00c98279d743a9784);
#
#
#         var popup_9cab232a9f85026eff6efdc9565576a6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1bee6bf468aa9f33cab12ffa4d82981e = $(`&lt;div id=&quot;html_1bee6bf468aa9f33cab12ffa4d82981e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archibald Finney&lt;/div&gt;`)[0];
#                 popup_9cab232a9f85026eff6efdc9565576a6.setContent(html_1bee6bf468aa9f33cab12ffa4d82981e);
#
#
#
#         circle_marker_7e24497574012939c1d78ddbbaaf2683.bindPopup(popup_9cab232a9f85026eff6efdc9565576a6)
#         ;
#
#
#
#
#             var circle_marker_ddef8ee4bcde0c44e881d61cc2dedfdc = L.circleMarker(
#                 [54.6715091273811, -5.773051048539186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a929a5ac99c609c00c98279d743a9784);
#
#
#         var popup_1ffb729589298ee984f4f40aff4ce055 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8c4358874e909a3ae63c732aa520ee16 = $(`&lt;div id=&quot;html_8c4358874e909a3ae63c732aa520ee16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City of Lucknow&lt;/div&gt;`)[0];
#                 popup_1ffb729589298ee984f4f40aff4ce055.setContent(html_8c4358874e909a3ae63c732aa520ee16);
#
#
#
#         circle_marker_ddef8ee4bcde0c44e881d61cc2dedfdc.bindPopup(popup_1ffb729589298ee984f4f40aff4ce055)
#         ;
#
#
#
#
#             var circle_marker_cbaee033d16642b20457a4db9e8f3bb4 = L.circleMarker(
#                 [55.27499801502037, -6.202576404675912],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a929a5ac99c609c00c98279d743a9784);
#
#
#         var popup_02f774da90421ad180c9c753f8eda164 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8d05629b56d4a396e81cb6f17660301f = $(`&lt;div id=&quot;html_8d05629b56d4a396e81cb6f17660301f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumberland&lt;/div&gt;`)[0];
#                 popup_02f774da90421ad180c9c753f8eda164.setContent(html_8d05629b56d4a396e81cb6f17660301f);
#
#
#
#         circle_marker_cbaee033d16642b20457a4db9e8f3bb4.bindPopup(popup_02f774da90421ad180c9c753f8eda164)
#         ;
#
#
#
#
#             var circle_marker_601aaebf2e56f17c84cce133314d57fd = L.circleMarker(
#                 [54.33125416454708, -5.498984966659973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;:

# %% [markdown]
# So that's nice, but it still doesn't answer our question - is there a correlation between depth and wreck frequency? Time to do some stats...

# %%
segment_table = ldf[ldf['segment'] > -1].groupby('segment').agg('count')

total_segmented = segment_table['Name'].sum()

def percentage(row):
    row['Count'] = row['Name']
    row['Blue Depth'] = bin_edges[row.name]
    row['% wrecks'] = 100 * row['Name'] / total_segmented
    row['% area'] = 100 * segment_fraction[row.name]
    row['Wreck Frequency'] = row['% wrecks'] / row['% area']
    return row

segment_table = segment_table.apply(percentage, axis=1)
segment_table = segment_table[['Count', 'Blue Depth', '% wrecks', '% area', 'Wreck Frequency']]
segment_table
# Out:
#          Count  Blue Depth  % wrecks     % area  Wreck Frequency
# segment
# 0          1.0    0.154842       5.0  10.912530         0.458189
# 1          3.0    0.173873      15.0  42.614025         0.351997
# 2         13.0    0.192903      65.0  32.343668         2.009667
# 3          3.0    0.211934      15.0  10.812775         1.387248

# %% [markdown]
# So not hugely, but around a third higher for the shallow (mostly coastal) areas. Not a huge gap, but oh well... it may be worth trying for other centuries though...

# %% [markdown]
# In any case, let's put it all together and see what our shipwreck map now looks like.

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

def add(wreck):
    pt = wreck.geometry

    if wreck['segment'] > -1:
        colour = colormap(wreck['segment'])
        folium.CircleMarker(
            [pt.y, pt.x],
            popup="%s (%.2lf, %.2lf)" % (wreck['Name'], wreck.geometry.y, wreck.geometry.x),
            fill_color=colour,
            fill_opacity=1,
            radius=8,
            color=colour
        ).add_to(fmap)

    return wreck

ldf.apply(add, axis=1)

tile = folium.raster_layers.ImageOverlay(
    name='coast',
    image=layers,
    bounds=layer_bounds,
    attr=attr,
    opacity=0.9,
    zindex=1
).add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5af57a59849ef572c761bf8e5f0a4f9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5af57a59849ef572c761bf8e5f0a4f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5af57a59849ef572c761bf8e5f0a4f9 = L.map(
#                 &quot;map_d5af57a59849ef572c761bf8e5f0a4f9&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7502ddfe1e5d13b5f3790f989cfeb1c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7502ddfe1e5d13b5f3790f989cfeb1c7.addTo(map_d5af57a59849ef572c761bf8e5f0a4f9);
#
#
#             var circle_marker_4dbf0795a3658b96231857e1d0ed420d = L.circleMarker(
#                 [54.44620042451414, -5.375600094540772],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff7f00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff7f00ff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d5af57a59849ef572c761bf8e5f0a4f9);
#
#
#         var popup_332e81319b772ec6f0a684853e9eea19 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_38edd680302d780adc7a4ce60e717538 = $(`&lt;div id=&quot;html_38edd680302d780adc7a4ce60e717538&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archibald Finney (54.45, -5.38)&lt;/div&gt;`)[0];
#                 popup_332e81319b772ec6f0a684853e9eea19.setContent(html_38edd680302d780adc7a4ce60e717538);
#
#
#
#         circle_marker_4dbf0795a3658b96231857e1d0ed420d.bindPopup(popup_332e81319b772ec6f0a684853e9eea19)
#         ;
#
#
#
#
#             var circle_marker_586d3d232df98e745f6045ac892e26dd = L.circleMarker(
#                 [54.6715091273811, -5.773051048539186],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff0000ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff0000ff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d5af57a59849ef572c761bf8e5f0a4f9);
#
#
#         var popup_0e90c7d31f2f4464d6f9c03ec1397310 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5b655713a8082f182de51817913b9a9 = $(`&lt;div id=&quot;html_d5b655713a8082f182de51817913b9a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;City of Lucknow (54.67, -5.77)&lt;/div&gt;`)[0];
#                 popup_0e90c7d31f2f4464d6f9c03ec1397310.setContent(html_d5b655713a8082f182de51817913b9a9);
#
#
#
#         circle_marker_586d3d232df98e745f6045ac892e26dd.bindPopup(popup_0e90c7d31f2f4464d6f9c03ec1397310)
#         ;
#
#
#
#
#             var circle_marker_eebcee0cc8c53f4c5f01875f52d64ac0 = L.circleMarker(
#                 [55.27499801502037, -6.202576404675912],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d5af57a59849ef572c761bf8e5f0a4f9);
#
#
#         var popup_5df3fab10e96ee2fc6db2c87f0638501 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ba34fc85aafacad6f492473e086f8edf = $(`&lt;div id=&quot;html_ba34fc85aafa

# %% [markdown]
# # Exercise

# %% [markdown]
# Try rerunning the above for different centuries. Do all centuries (with data) have similar results? Does this tell you something about seafaring over time? Are all century datasets equally valid for analysis?

# %% [markdown]
# # Answers

# %%
import dateutil

def get_century(dt):
    date = None

    if dt:
        try:
            date = dateutil.parser.parse(dt)
        except ValueError:
            pass
        else:
            if date and date.year:
                date = str(date.year)[0:2]
            else:
                date = None

    return date
