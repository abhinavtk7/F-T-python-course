# %% [markdown]
# # Wreckognition

# %% [markdown]
# In this section, we will see a few examples of:
# * geographic tools
# * using numpy to manipulate images
# * applying image filters
# * segmentation
# * ML-style clustering

# %% [markdown]
# We will use DAERA's list of protected shipwrecks, hosted by OpenDataNI. For more information, see the [page on their site](https://www.opendatani.gov.uk/dataset/protected-wreck-sites).

# %% [markdown]
# Using these tools, we hope to answer the questions:
#
# > Do wrecks cluster near groups of ports?
#
# and
#
# > Are wrecks more common in deep water or shallow water?

# %% [markdown]
# We may even try to see whether shipwrecks in the 1800s, 1900s or 2000s have different likely locations.

# %% [markdown]
# To begin, we will open up the downloaded dataset using geopandas - this is an extended version of pandas that can attach geographic (or geometric) attributes to each row.

# %% [markdown]
# ## Geopandas

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('protected_wrecks.geojson')

# %%
type(gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdf
# Out:
#                    Name   Date_lost                              Type  \
# 0                 Ailsa  26/02/1892               Steamship (British)
# 1      (ex HMS) Alastor  11/03/1946  Corvette / Motor yacht (British)
# 2         Albia (poss.)  28/09/1929             Spanish tramp steamer
# 3                Alcedo  ??/01/1892                     Steam coaster
# 4                 Alder        None                              None
# ..                  ...         ...                               ...
# 335             Unknown        None                             Wreck
# 336  Vought F4U Corsair  09/10/1944                          Aircraft
# 337             Unknown        None                             Wreck
# 338             Unknown        None                             Wreck
# 339         HMS Curacao  02/10/1942             C-Class light cruiser
#
#           Cargo   Depth   Position_q  \
# 0       General    1-5m   Reasonable
# 1          None  10-23m     Accurate
# 2    Copper ore     10m  Approximate
# 3          Coal      7m  Approximate
# 4          None     -3m  Approximate
# ..          ...     ...          ...
# 335        None    None     Accurate
# 336        None    None  Approximate
# 337        None    125m     Accurate
# 338        None    139m     Accurate
# 339        None    None         None
#
#                                              Condition             Ref Status  \
# 0            Badly broken up, part of wreck is onshore  UKHO, IRW, CMA   LIVE
# 1    Llargely intact with upright funnel. Wooden de...  UKHO, IRW, CMA   LIVE
# 2                                    5m high, upright.  IRW, UKHO, CMA   LIVE
# 3                           2.5m high, badly broken up        IRW, CMA   LIVE
# 4                                                 None            UKHO   LIFT
# ..                                                 ...             ...    ...
# 335  Concentraion of possible ships timbers protrud...        MFD 2016   None
# 336                                           Wreckage        MFD 2017   None
# 337  The wreck appears to be mostly intact and is a...       AFBI 2017   None
# 338  The wreck appears to be mostly intact and is a...       AFBI 2017   None
# 339                                               None            None   None
#
#                                                Notes  ...   X_Coord  \
# 0                                               None  ... -5.738217
# 1                                               None  ... -5.629383
# 2                                               None  ... -5.741317
# 3                                               None  ... -5.696200
# 4                                 Wreck removed 1938  ... -6.098500
# ..                                               ...  ...       ...
# 335        Observed during foreshore survey 08/11/16  ... -6.208401
# 336    Vought F4U Corsair fighter (serial no. JT693)  ... -7.040083
# 337  Wreck located during 2017 AFBI multibeam survey  ...  0.000000
# 338  Wreck located during 2017 AFBI multibeam survey  ...  0.000000
# 339                                             None  ...  0.000000
#
#        Y_Coord     Updated  Nation   How_lost  \
# 0    54.852500        None    None       None
# 1    54.451550        None    None       None
# 2    54.949933        None    None       None
# 3    54.815483        None    None       None
# 4    54.053217        None    None       None
# ..         ...         ...     ...        ...
# 335  54.096844  2016-11-08    None       None
# 336  55.072610  2017-02-21    None       None
# 337   0.000000  2017-07-04    None       None
# 338   0.000000  2017-07-04    None       None
# 339   0.000000        None    None  Collision
#
#                              Legislatio  \
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
# 4                                  None
# ..                                  ...
# 335                                None
# 336                                None
# 337                                None
# 338                                None
# 339  Protection Military Remains (1986)
#
#                                             Notes_1           Origin  \
# 0                                              None             None
# 1                                              None             None
# 2                                              None             None
# 3                                              None             None
# 4                                              None             None
# ..                                              ...              ...
# 335                                            None             None
# 336                                            None             None
# 337                                            None             None
# 338                                            None             None
# 339  Designated protected place. Position uncertain  Admiralty owned
#
#              Where_lost                   geometry
# 0                  None  POINT (-5.73822 54.85250)
# 1                  None  POINT (-5.62938 54.45155)
# 2                  None  POINT (-5.74132 54.94993)
# 3                  None  POINT (-5.69620 54.81548)
# 4                  None  POINT (-6.09850 54.05322)
# ..                  ...                        ...
# 335                None  POINT (-6.20840 54.09684)
# 336                None  POINT (-7.04008 55.07261)
# 337                None  POINT (-5.76075 55.09920)
# 338                None  POINT (-5.64846 55.02999)
# 339  60km N of Ireland?  POINT (-6.75512 55.70542)
#
# [340 rows x 24 columns]

# %% [markdown]
# Exploring this data, we see a range of ships - also a few data quality issues in the dates and missing values.
#
# If you have a look at the last, "geometry", column, you will see an entity in WKT (well-known text) format - a computer-readable way of specifying entities.

# %% [markdown]
# We can use matplotlib to take a look.

# %%
# %matplotlib inline

# %%
gdf.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## What? That's not a map

# %% [markdown]
# OK, so that's a scatterplot, which isn't much of a map. We have seen how Python allows us to easily combine different tools and modes of expression. We can use a package called `folium` to make OpenStreetMap / Google Maps style interactive maps.

# %%
import folium

# %% [markdown]
# Naturally, before we show a useful map, we need to decide how to centre it somewhere relevant.

# %% [markdown]
# As it happens, the point associated with each row in geopandas is a `Shapely` geometric entity. It could also be a line, polygon, circle, or a combination of those, for example. We can also ask for the `gdf.geometry`, which is the collection of all the row entities.
#
# Shapely is a geometric package - this means we can do geometric operations on the rows. For example, we can combine all the points into one polka-dot geometric entity - a union operation.

# %%
gdf.geometry.unary_union
# Out:
# <MULTIPOINT (-7.315 55.001, -7.309 55.01, -7.309 55.012, -7.294 55.017, -7.2...>

# %% [markdown]
# As a 2d geometric entity, it also has a centroid - a weighted midpoint - which will suffice for us to centre our map.

# %%
middle = gdf.geometry.unary_union.centroid
middle
# Out:
# <POINT (-5.825 54.644)>

# %% [markdown]
# Geometric manipulation is much more useful than mapping - it is critical in many forms of numerical analysis, engineering, design and 3d printing. Explore Shapely's toolkit at your leisure.

# %% [markdown]
# ## Map time

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

def add(wreck):
    pt = wreck.geometry
    folium.Marker(
        [pt.y, pt.x],
        popup=wreck['Name'],
    ).add_to(fmap)
    return wreck

gdf = gdf.apply(add, axis=1)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e05e0a77367fa343c1dece84bc3c35b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e05e0a77367fa343c1dece84bc3c35b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e05e0a77367fa343c1dece84bc3c35b = L.map(
#                 &quot;map_9e05e0a77367fa343c1dece84bc3c35b&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a28bfb55ccab8b7388941c18794aa255 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e05e0a77367fa343c1dece84bc3c35b);
#
#
#             var marker_cbc18c4fafaa574a1de443758d0f5797 = L.marker(
#                 [54.852500423720116, -5.738216765202008],
#                 {}
#             ).addTo(map_9e05e0a77367fa343c1dece84bc3c35b);
#
#
#         var popup_6bd0b39872c74666baf625e7573edaa2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3233436593e4171dc0399841241c6f6 = $(`&lt;div id=&quot;html_b3233436593e4171dc0399841241c6f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_6bd0b39872c74666baf625e7573edaa2.setContent(html_b3233436593e4171dc0399841241c6f6);
#
#
#
#         marker_cbc18c4fafaa574a1de443758d0f5797.bindPopup(popup_6bd0b39872c74666baf625e7573edaa2)
#         ;
#
#
#
#
#             var marker_d9bf13d3f04390a1750faaf6ffdaf79d = L.marker(
#                 [54.45155042371992, -5.629383430791251],
#                 {}
#             ).addTo(map_9e05e0a77367fa343c1dece84bc3c35b);
#
#
#         var popup_845ab56181d46961a52b5e0bd121a74f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ee301fe2b09161d94d689a84b2377e99 = $(`&lt;div id=&quot;html_ee301fe2b09161d94d689a84b2377e99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;(ex HMS) Alastor&lt;/div&gt;`)[0];
#                 popup_845ab56181d46961a52b5e0bd121a74f.setContent(html_ee301fe2b09161d94d689a84b2377e99);
#
#
#
#         marker_d9bf13d3f04390a1750faaf6ffdaf79d.bindPopup(popup_845ab56181d46961a52b5e0bd121a74f)
#         ;
#
#
#
#
#             var marker_e7352a0d12e793a014d25e86281c3bcf = L.marker(
#                 [54.94993342278837, -5.741317099083887],
#                 {}
#             ).addTo(map_9e05e0a77367fa343c1dece84bc3c35b);
#
#
#         var popup_7321709fd48fad40a9a18ea7c9cd3992 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2576123827ad0df3c78199290e26b0ea = $(`&lt;div id=&quot;html_2576123827ad0df3c78199290e26b0ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Albia (poss.)&lt;/div&gt;`)[0];
#                 popup_7321709fd48fad40a9a18ea7c9cd3992.setContent(html_2576123827ad0df3c78199290e26b0ea);
#
#
#
#         marker_e7352a0d12e793a014d25e86281c3bcf.bindPopup(popup_7321709fd48fad40a9a18ea7c9cd3992)
#         ;
#
#
#
#
#             var marker_86a2f7c06a4de5ef171b8080c8b2e347 = L.marker(
#                 [54.81548342367984, -5.696200098805885],
#                 {}
#             ).addTo(map_9e05e0a77367fa343c1dece84bc3c35b);
#
#
#         var popup_fc3958f5cb7b3b691b08584ed0f2ea88 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_85bfc544b4ba9927f2841a4643493e23 = $(`&lt;div id=&quot;html_85bfc544b4ba9927f2841a4643493e23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alcedo&lt;/div&gt;`)[0];
#                 popup_fc3958f5cb7b3b691b08584ed0f2ea88.setContent(html_85bfc544b4ba9927f2841a4643493e23);
#
#
#
#         marker_86a2f7c06a4de5ef171b8080c8b2e347.bindPopup(popup_fc3958f5cb7b3b691b08584ed0f2ea88)
#         ;
#
#
#
#
#             var marker_b5a63b72fb9d5a76b6ace8b9e3f02dfa = L.marker(
#                 [54.05321709066201, -6.098500100507256],
#                 {}
#             ).addTo(map_9e05e0a77367fa343c1dece84bc3c35b);
#
#
#         var popup_6428cdea67ecfe90cb0364dc89b7b741 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_083e042b7da5263f2ff95316f12a16b7 = $(`&lt;div id=&quot;html_083e042b7da5263f2ff95316f12a16b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Alder&lt;/div&gt;`)[0];
#                 popup_6428cdea67ecfe90cb0364dc89b7b741.setContent(html_083e042b7da5263f2ff95316f12a16b7);
#
#
#
#         marker_b5a63b72fb9d5a76b6ace8b9e3f02dfa.bindPopup(popup_6428cdea67ecfe90cb0364dc89b7b741)
#         ;
#
#
#
#
#             var marker_7604721e823cfd09581

# %% [markdown]
# That should be familiar - as previously, we use the `apply` method on a dataframe to iterate through it (a geopandas geodataframe, but it's essentially the same idea). In each step, we add a marker to the map.
#
# In the first line, we create a map, setting the centre and zoom. For each wreck, we add its coordinates to a new folium `Marker` and call the `add_to` method to append it to the map.

# %% [markdown]
# ## Exercise

# %% [markdown]
# Can you write a function that will take a string entry (it will be the content of the Date_Lost column) and return a string representing the century - '18', '19' or '20' - or None if it is not one of those?

# %% [markdown]
# CLUE: `dateutil` has a parser that can make a best guess at which date a string represents: `dateutil.parser.parse(dt)`

# %%
import dateutil
from datetime import datetime

def get_century(dt):
  try:
    if dt is None:
      dt = ''
    date_object = datetime.strptime(dt, '%d/%m/%Y')
    # Extract the year from the datetime object
    year = date_object.year

    # Calculate the century
    if year % 100 == 0:
        century = year // 100
    else:
        century = (year // 100) + 1

    return str(century)
  except ValueError:
    return None

# %% [markdown]
# Now we can add a `century` column to the data.

# %%
def add(wreck):
    wreck['century'] = get_century(wreck['Date_lost'])
    return wreck

gdf = gdf.apply(add, axis=1)
gdf.head()
# Out:
#                Name   Date_lost                              Type       Cargo  \
# 0             Ailsa  26/02/1892               Steamship (British)     General
# 1  (ex HMS) Alastor  11/03/1946  Corvette / Motor yacht (British)        None
# 2     Albia (poss.)  28/09/1929             Spanish tramp steamer  Copper ore
# 3            Alcedo  ??/01/1892                     Steam coaster        Coal
# 4             Alder        None                              None        None
#
#     Depth   Position_q                                          Condition  \
# 0    1-5m   Reasonable          Badly broken up, part of wreck is onshore
# 1  10-23m     Accurate  Llargely intact with upright funnel. Wooden de...
# 2     10m  Approximate                                  5m high, upright.
# 3      7m  Approximate                         2.5m high, badly broken up
# 4     -3m  Approximate                                               None
#
#               Ref Status               Notes  ...    Y_Coord Updated Nation  \
# 0  UKHO, IRW, CMA   LIVE                None  ...  54.852500    None   None
# 1  UKHO, IRW, CMA   LIVE                None  ...  54.451550    None   None
# 2  IRW, UKHO, CMA   LIVE                None  ...  54.949933    None   None
# 3        IRW, CMA   LIVE                None  ...  54.815483    None   None
# 4            UKHO   LIFT  Wreck removed 1938  ...  54.053217    None   None
#
#    How_lost  Legislatio  Notes_1 Origin Where_lost                   geometry  \
# 0      None        None     None   None       None  POINT (-5.73822 54.85250)
# 1      None        None     None   None       None  POINT (-5.62938 54.45155)
# 2      None        None     None   None       None  POINT (-5.74132 54.94993)
# 3      None        None     None   None       None  POINT (-5.69620 54.81548)
# 4      None        None     None   None       None  POINT (-6.09850 54.05322)
#
#   century
# 0      19
# 1      20
# 2      20
# 3    None
# 4    None
#
# [5 rows x 25 columns]

# %%
type(gdf['century'][0])
# Out:
# str

# %% [markdown]
# Many points don't have a century, but lets ignore that for now.

# %% [markdown]
# Folium also lets us group markers. This is much more useful. Here we create several `FeatureGroup` map layers and them to the map. We then add markers directly to each century's FeatureGroup with coloured icons. At the end, we add a layer control, so you can turn each group on and off.

# %%
type(gdf['century'][0])
# Out:
# numpy.float64

# %%
middle.y
# Out:
# 54.64427445282978

# %%
from folium import FeatureGroup, LayerControl

fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

centuries = {
    '18': 'red',
    '19': 'green',
    '20': 'blue'
}
clusters = {}

for century, colour in centuries.items():
    clusters[century] = FeatureGroup(name=century)
    clusters[century].add_to(fmap)

def add(wreck):
    wreck['century'] = get_century(wreck['Date_lost'])

    pt = wreck.geometry
    if wreck['century'] in centuries:
        colour = centuries[wreck['century']]
        folium.Marker(
            [pt.y, pt.x],
            popup=wreck['Name'],
            icon=folium.Icon(color=colour)
        ).add_to(clusters[wreck['century']])

    return wreck

# %%
gdf = gdf.apply(add, axis=1)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_329027f5551dc4664a1b88d8bfbf55a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_329027f5551dc4664a1b88d8bfbf55a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_329027f5551dc4664a1b88d8bfbf55a2 = L.map(
#                 &quot;map_329027f5551dc4664a1b88d8bfbf55a2&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8cf73540dd8041df6b5e9dd98c7a7fbf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_329027f5551dc4664a1b88d8bfbf55a2);
#
#
#             var feature_group_4afb2f1d773b97c6a370f261cb43de7b = L.featureGroup(
#                 {}
#             ).addTo(map_329027f5551dc4664a1b88d8bfbf55a2);
#
#
#             var marker_83eb60735ef39d1a72dea122bedeac59 = L.marker(
#                 [54.952095592630954, -5.744053278344665],
#                 {}
#             ).addTo(feature_group_4afb2f1d773b97c6a370f261cb43de7b);
#
#
#             var icon_42f8dc7231818732ba87beeb947eed3a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_83eb60735ef39d1a72dea122bedeac59.setIcon(icon_42f8dc7231818732ba87beeb947eed3a);
#
#
#         var popup_36709999eecfbae27e286b98a98b9b7a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1e7704da3c6c0864a12c2a8ef6c5390c = $(`&lt;div id=&quot;html_1e7704da3c6c0864a12c2a8ef6c5390c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Unknown&lt;/div&gt;`)[0];
#                 popup_36709999eecfbae27e286b98a98b9b7a.setContent(html_1e7704da3c6c0864a12c2a8ef6c5390c);
#
#
#
#         marker_83eb60735ef39d1a72dea122bedeac59.bindPopup(popup_36709999eecfbae27e286b98a98b9b7a)
#         ;
#
#
#
#
#             var marker_9fcb6128fd800b74637907569d434718 = L.marker(
#                 [55.22225365268374, -6.629235293324471],
#                 {}
#             ).addTo(feature_group_4afb2f1d773b97c6a370f261cb43de7b);
#
#
#             var icon_2196e375f328033e2835d0eeb51272ee = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9fcb6128fd800b74637907569d434718.setIcon(icon_2196e375f328033e2835d0eeb51272ee);
#
#
#         var popup_725076f14fbee06de2289a0d0bca6efe = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c8f993fa44ee16cb382a462f4035152 = $(`&lt;div id=&quot;html_3c8f993fa44ee16cb382a462f4035152&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;N/A&lt;/div&gt;`)[0];
#                 popup_725076f14fbee06de2289a0d0bca6efe.setContent(html_3c8f993fa44ee16cb382a462f4035152);
#
#
#
#         marker_9fcb6128fd800b74637907569d434718.bindPopup(popup_725076f14fbee06de2289a0d0bca6efe)
#         ;
#
#
#
#
#             var feature_group_b18c6533e9f4cf9571f26ea4b2632257 = L.featureGroup(
#                 {}
#             ).addTo(map_329027f5551dc4664a1b88d8bfbf55a2);
#
#
#             var marker_d4e2076a8042ff71ec8d79e70799ad8d = L.marker(
#                 [54.852500423720116, -5.738216765202008],
#                 {}
#             ).addTo(feature_group_b18c6533e9f4cf9571f26ea4b2632257);
#
#
#             var icon_1aa9ceda601d95fa451b462e051278e1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d4e2076a8042ff71ec8d79e70799ad8d.setIcon(icon_1aa9ceda601d95fa451b462e051278e1);
#
#
#         var popup_09a2fc96da3c68b6a21521a7723fd6fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d933660a04a75ec17c0101c38679aea8 = $(`&lt;div id=&quot;html_d933660a04a75ec17c0101c38679aea8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_09a2fc96da3c68b6a21521a7723fd6fa.setContent(html_d933660a04a75ec17c0101c38679aea8);
#
#
#
#         marker_d4e2076a8042ff71ec8d79e70799ad8d.bindPopup(popup_09a2fc96da3c68b6a

# %% [markdown]
# ## Changing of the Seasons

# %% [markdown]
# Let's pick a century. 1900's, for example.

# %%
century = '19' # if you want to try a different century, come back here, change this and run the cells below

# %%
# kmeans isn't the best option, as lat-long is not linear and we are guessing cluster numbers,
# but this illustrates how it can work
from sklearn.cluster import KMeans
import numpy as np

gdf['label'] = -1
kdf = gdf[gdf['century'] == century]
locations = np.array([[w.geometry.y, w.geometry.x] for n, w in kdf.iterrows()])
locations
# Out:
# array([[54.85250042, -5.73821677],
#        [54.44620042, -5.37560009],
#        [54.85368342, -5.7697831 ],
#        [54.78753342, -5.6885831 ],
#        [54.67150913, -5.77305105],
#        [55.27499802, -6.2025764 ],
#        [54.33125416, -5.49898497],
#        [54.06666709, -5.95833343],
#        [54.85222589, -5.7908119 ],
#        [55.29536126, -6.28592233],
#        [54.43380042, -5.39493309],
#        [55.26420184, -6.19813141],
#        [54.58333342, -5.4833331 ],
#        [55.27752641, -6.17896666],
#        [54.28088376, -5.52776676],
#        [54.53983376, -5.45181565],
#        [54.95288342, -5.7302501 ],
#        [54.38882984, -5.56496278],
#        [55.19286713, -6.70915706],
#        [54.88200042, -5.75271677],
#        [54.95286742, -5.7302501 ],
#        [54.69685785, -5.5302748 ],
#        [55.14917541, -6.02282832],
#        [55.29163042, -6.2468801 ],
#        [55.20695042, -6.60878344],
#        [53.95381709, -5.92096677],
#        [55.16916709, -6.75961678],
#        [54.88255042, -5.75188343]])

# %% [markdown]
# Now we set up our k-means algorithm - this involves choosing an expected number of clusters - and fit it to our locations list. It generates a numpy array of labels, one entry for each location representing its cluster.

# %%
kmeans = KMeans(n_clusters=6).fit(locations)
kmeans.labels_
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 3, 0, 0, 0, 1, 3, 2, 0, 1, 3, 1, 5, 1, 3, 5, 0, 3, 4, 0, 0, 5,
#        1, 1, 4, 2, 4, 0], dtype=int32)

# %% [markdown]
# We can then add these in the specific entries in the dataframe.

# %%
for n, label in enumerate(kmeans.labels_):
    gdf.loc[kdf.index[n], 'label'] = label

kdf = gdf[gdf['century'] == century]
kdf.loc[:, 'label'].head()
# Out:
# 0     0
# 10    3
# 18    0
# 22    0
# 29    0
# Name: label, dtype: int64

# %% [markdown]
# How does this look on the original map?

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

colours = ['red', 'green', 'blue', 'orange', 'pink', 'gray']
clusters = {}

for label, colour in enumerate(colours):
    clusters[label] = FeatureGroup(name="Cluster %d" % label)
    clusters[label].add_to(fmap)

def add(wreck):
    pt = wreck.geometry

    colour = colours[wreck['label']]
    folium.Marker(
        [pt.y, pt.x],
        popup=wreck['Name'],
        icon=folium.Icon(color=colour)
    ).add_to(clusters[wreck['label']])

    return wreck

kdf = kdf.apply(add, axis=1)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5543493375f1ee8ab1aedd5eb7c78105 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5543493375f1ee8ab1aedd5eb7c78105&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5543493375f1ee8ab1aedd5eb7c78105 = L.map(
#                 &quot;map_5543493375f1ee8ab1aedd5eb7c78105&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e43f89f7235deaf127a0d97a38ad311 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5543493375f1ee8ab1aedd5eb7c78105);
#
#
#             var feature_group_49e185750fe002af442066e1bf380781 = L.featureGroup(
#                 {}
#             ).addTo(map_5543493375f1ee8ab1aedd5eb7c78105);
#
#
#             var marker_9b2ad6f76a6cc5d85e3c64ff67d95f68 = L.marker(
#                 [54.852500423720116, -5.738216765202008],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_e6e5b8b2e3aa5e8bdac59b87f6f64a86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b2ad6f76a6cc5d85e3c64ff67d95f68.setIcon(icon_e6e5b8b2e3aa5e8bdac59b87f6f64a86);
#
#
#         var popup_326a69a80162c2537be61a08c68efd98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3bd888e03377223e9f14c08de2f810c = $(`&lt;div id=&quot;html_b3bd888e03377223e9f14c08de2f810c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_326a69a80162c2537be61a08c68efd98.setContent(html_b3bd888e03377223e9f14c08de2f810c);
#
#
#
#         marker_9b2ad6f76a6cc5d85e3c64ff67d95f68.bindPopup(popup_326a69a80162c2537be61a08c68efd98)
#         ;
#
#
#
#
#             var marker_e1b92bf1138c5b399a3d11f818d64acf = L.marker(
#                 [54.85368342338922, -5.769783098801826],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_304bb61703eb1b3beb488f09dd8ee98f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e1b92bf1138c5b399a3d11f818d64acf.setIcon(icon_304bb61703eb1b3beb488f09dd8ee98f);
#
#
#         var popup_731860616beec41f01699cc607ec4615 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21bb6d191f90c8246f1b9d1b27ac6100 = $(`&lt;div id=&quot;html_21bb6d191f90c8246f1b9d1b27ac6100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berbice&lt;/div&gt;`)[0];
#                 popup_731860616beec41f01699cc607ec4615.setContent(html_21bb6d191f90c8246f1b9d1b27ac6100);
#
#
#
#         marker_e1b92bf1138c5b399a3d11f818d64acf.bindPopup(popup_731860616beec41f01699cc607ec4615)
#         ;
#
#
#
#
#             var marker_13df5c7e01956dbf53515672523ab8af = L.marker(
#                 [54.78753342353975, -5.688583098146545],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_bfaa0bf5e42ab9969769863dadc6566a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_13df5c7e01956dbf53515672523ab8af.setIcon(icon_bfaa0bf5e42ab9969769863dadc6566a);
#
#
#         var popup_6b18dd27659a5e5945d275089aaecd25 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_574ef3a5bc6c5a48bedd603ce58b1306 = $(`&lt;div id=&quot;html_574ef3a5bc6c5a48bedd603ce58b1306&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Black Diamond&lt;/div&gt;`)[0];
#                 popup_6b18dd27659a5e5945d275089aaecd25.setContent(html_574ef3a5bc6c5a48bedd603ce58b1306);
#
#
#
#         marker_13df5c7e01956dbf53515672523ab8af.bindPopup(popup_6b18dd27659a5e5945d275089aaecd25)
#         ;
#
#
#
#
#             var marker_a91e43bfbe3cbf43f4fdb88678d3af66 = L.marker(
#                 [54.6715091273811, -5.7730510485391

# %% [markdown]
# # Quiz
#
# * Which of NI's main harbours match to which clusters?
# * How does it change with the number of labels you use?
# * How does it change with the century?

# %% [markdown]
# # Looks deep

# %% [markdown]
# Next question: is there a correlation between depth and number of shipwrecks?
#
# Rather than using the official bathymetry data, we will try and guess depth from shades of blue in satellite images. There's a few issues with our approach here - such as the resolution of the images, the processing that's already been done to them, the fact that colour isn't necessarily a good proxy for depth - but it will demonstrate how we can use image manipulation to back up other analysis.

# %% [markdown]
# First, we show the Sentinel-2 open satellite data as a map layer.

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

attr = """
<i>
<a class="a-light" xmlns:dct="http://purl.org/dc/terms/"
      href="https://s2maps.eu" property="dct:title">
  Sentinel-2 cloudless - https://s2maps.eu
</a> by
<a class="a-light" xmlns:cc="http://creativecommons.org/ns#"
      href="https://eox.at" property="cc:attributionName"
      rel="cc:attributionURL">
  EOX IT Services GmbH
</a><br/>
(Contains modified Copernicus Sentinel data 2016 &amp; 2017)</i>
"""
sentinel = folium.WmsTileLayer(
    url='https://tiles.maps.eox.at/wms',
    name='s2maps.eu',
    fmt='image/png',
    attr=attr,
    layers='s2cloudless_3857'
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

attr = """
<i>
<a class="a-light" xmlns:dct="http://purl.org/dc/terms/"
      href="https://s2maps.eu" property="dct:title">
  Sentinel-2 cloudless - https://s2maps.eu
</a> by
<a class="a-light" xmlns:cc="http://creativecommons.org/ns#"
      href="https://eox.at" property="cc:attributionName"
      rel="cc:attributionURL">
  EOX IT Services GmbH
</a><br/>
(Contains modified Copernicus Sentinel data 2016 &amp; 2017)</i>
"""
sentinel = folium.WmsTileLayer(
    url='https://tiles.maps.eox.at/wms',
    name='s2maps.eu',
    fmt='image/png',
    attr=attr,
    layers='s2cloudless_3857'
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a1d147bddf24e4e97e85f64da85ab00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a1d147bddf24e4e97e85f64da85ab00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a1d147bddf24e4e97e85f64da85ab00 = L.map(
#                 &quot;map_0a1d147bddf24e4e97e85f64da85ab00&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca7fcc2c1d4453dc111629a720c2a65c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0a1d147bddf24e4e97e85f64da85ab00);
#
#
#             var macro_element_feacb0dfcc030f743eaaefd945cc3a8c = L.tileLayer.wms(
#                 &quot;https://tiles.maps.eox.at/wms&quot;,
#                 {&quot;attribution&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;s2cloudless_3857&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: false, &quot;version&quot;: &quot;1.1.1&quot;}
#             ).addTo(map_0a1d147bddf24e4e97e85f64da85ab00);
#
#
#             var feature_group_49e185750fe002af442066e1bf380781 = L.featureGroup(
#                 {}
#             ).addTo(map_0a1d147bddf24e4e97e85f64da85ab00);
#
#
#             var marker_9b2ad6f76a6cc5d85e3c64ff67d95f68 = L.marker(
#                 [54.852500423720116, -5.738216765202008],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_e6e5b8b2e3aa5e8bdac59b87f6f64a86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b2ad6f76a6cc5d85e3c64ff67d95f68.setIcon(icon_e6e5b8b2e3aa5e8bdac59b87f6f64a86);
#
#
#         var popup_326a69a80162c2537be61a08c68efd98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3bd888e03377223e9f14c08de2f810c = $(`&lt;div id=&quot;html_b3bd888e03377223e9f14c08de2f810c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_326a69a80162c2537be61a08c68efd98.setContent(html_b3bd888e03377223e9f14c08de2f810c);
#
#
#
#         marker_9b2ad6f76a6cc5d85e3c64ff67d95f68.bindPopup(popup_326a69a80162c2537be61a08c68efd98)
#         ;
#
#
#
#
#             var marker_e1b92bf1138c5b399a3d11f818d64acf = L.marker(
#                 [54.85368342338922, -5.769783098801826],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_304bb61703eb1b3beb488f09dd8ee98f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e1b92bf1138c5b399a3d11f818d64acf.setIcon(icon_304bb61703eb1b3beb488f09dd8ee98f);
#
#
#         var popup_731860616beec41f01699cc607ec4615 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21bb6d191f90c8246f1b9d1b27ac6100 = $(`&lt;div id=&quot;html_21bb6d191f90c8246f1b9d1b27ac6100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berbice&lt;/div&gt;`)[0];
#                 popup_731860616beec41f01699cc607ec4615.setContent(html_21bb6d191f90c8246f1b9d1b27ac6100);
#
#
#
#         marker_e1b92bf1138c5b399a3d11f818d64acf.bindPopup(popup_731860616beec41f01699cc607ec4615)
#         ;
#
#
#
#
#             var marker_13df5c7e01956dbf53515672523ab8af = L.marker(
#                 [54.78753342353975, -5.688583098146545],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_bfaa0bf5e42ab9969769863dadc6566a = L.AwesomeMarkers.icon

# %% [markdown]
# Rather than examining _all_ this data - I have chopped out a tile for our convenience. An image we can manipulate...

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

tile = folium.raster_layers.ImageOverlay(
    url='https://tiles.maps.eox.at/wms',
    name='coast',
    image='coast.jpg',
    fmt='jpg',
    bounds=[[53.81683262680313, -6.78096405771856],[55.45928868149063, -5.14400116709356]],
    attr=attr,
    opacity=0.6,
    zindex=1
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99ae7677543ab598c6e11b1ffc29a846 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99ae7677543ab598c6e11b1ffc29a846&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99ae7677543ab598c6e11b1ffc29a846 = L.map(
#                 &quot;map_99ae7677543ab598c6e11b1ffc29a846&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0f4be0eb934bb7088d302a26606067c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_99ae7677543ab598c6e11b1ffc29a846);
#
#
#             var image_overlay_fb15e9160075dad0f523cfbb60644d4c = L.imageOverlay(
#                 &quot;data:image/jpg;base64,...&quot;,
#                 [[53.81683262680313, -6.78096405771856], [55.45928868149063, -5.14400116709356]],
#                 {&quot;attr&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;, &quot;fmt&quot;: &quot;jpg&quot;, &quot;opacity&quot;: 0.6, &quot;url&quot;: &quot;https://tiles.maps.eox.at/wms&quot;, &quot;zindex&quot;: 1}
#             ).addTo(map_99ae7677543ab598c6e11b1ffc29a846);
#
#
#             var feature_group_49e185750fe002af442066e1bf380781 = L.featureGroup(
#                 {}
#             ).addTo(map_99ae7677543ab598c6e11b1ffc29a846);
#
#
#             var marker_9b2ad6f76a6cc5d85e3c64ff67d95f68 = L.marker(
#                 [54.852500423720116, -5.738216765202008],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_e6e5b8b2e3aa5e8bdac59b87f6f64a86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b2ad6f76a6cc5d85e3c64ff67d95f68.setIcon(icon_e6e5b8b2e3aa5e8bdac59b87f6f64a86);
#
#
#         var popup_326a69a80162c2537be61a08c68efd98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3bd888e03377223e9f14c08de2f810c = $(`&lt;div id=&quot;html_b3bd888e03377223e9f14c08de2f810c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_326a69a80162c2537be61a08c68efd98.setContent(html_b3bd888e03377223e9f14c08de2f810c);
#
#
#
#         marker_9b2ad6f76a6cc5d85e3c64ff67d95f68.bindPopup(popup_326a69a80162c2537be61a08c68efd98)
#         ;
#
#
#
#
#             var marker_e1b92bf1138c5b399a3d11f818d64acf = L.marker(
#                 [54.85368342338922, -5.769783098801826],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_304bb61703eb1b3beb488f09dd8ee98f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e1b92bf1138c5b399a3d11f818d64acf.setIcon(icon_304bb61703eb1b3beb488f09dd8ee98f);
#
#
#         var popup_731860616beec41f01699cc607ec4615 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21bb6d191f90c8246f1b9d1b27ac6100 = $(`&lt;div id=&quot;html_21bb6d191f90c8246f1b9d1b27ac6100&quot;

# %% [markdown]
# Now, how do we actually use a picture like data? scikit-image (skimage) has a lot of image manipulation tools - these can be coupled with scikit-learn in certain contexts to do image-based machine learning, so this is a brief intro.

# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage
# %matplotlib inline

# %%
coast = skimage.io.imread('coast.jpg')
plt.imshow(coast)

# %% [markdown]
# We have actually imported this image as a numpy array. In fact, this is actually plotting using the same technique as our Inflammation numpy tutorial - it's a graph of cells, where each cell has colour values. Pixels you might say...

# %%
coast[0, 0, :]
# Out:
# array([14, 33, 48], dtype=uint8)

# %% [markdown]
# First, we soften some of the noise using a Gaussian blur.

# %%
from skimage import filters

smooth = filters.gaussian(coast, sigma=10, multichannel=True)
plt.imshow(smooth)
# Out:
# <ipython-input-57-32b55e7de014>:3: FutureWarning: `multichannel` is a deprecated argument name for `gaussian`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   smooth = filters.gaussian(coast, sigma=10, multichannel=True)

# %% [markdown]
# As this is a 3d matrix, as far as numpy is concerned, we can extract a single colour channel using a slice. Here is the green one (think RGB - G has index 1).

# %%
plt.imshow(smooth[:,:,1])

# %% [markdown]
# A simple, coarse way to trim all the non-sea (land, as it's known) is to pick everything that is more than a little green. Here we set anything with more than 0.2 in the green column to black.

# %%
smooth[smooth[:,:,1] > 0.2] = [0, 0, 0]
plt.imshow(smooth)

# %% [markdown]
# Next, we go one step further, by selecting _just_ the blue channel and trimming (setting to -1) everything that is outside of an emperical or heuristic (i.e. guessed or made up) window.

# %%
sea = smooth[:,:,2].copy()
sea[(sea < 0.1) | (sea > 0.25)] = -1
plt.imshow(sea)

# %% [markdown]
# OK, so we have some sea now - we know where it is. Now lets split it into layers of deep and shallow. To do this, we use a basic image segmentation technique, which is no more than numpy's `histogram` function. This puts all of our pixels into labeled "bins" (or layers, in our 2d image case).

# %%
# This number is our own choice of sea-depth layers
bins = 5

# We split up the sea into a set of bins
hist, bin_edges = np.histogram(
    sea,
    bins=bins,
    range=(sea[sea > 0].min(), sea.max())
)

# And create a new array called layers that matches each pixel to a depth layer: shallow...deep
last_edge = bin_edges[0]
layers = np.zeros(sea.shape, dtype=int) - 1
for n, next_edge in enumerate(bin_edges[1:]):
    layers[(sea > last_edge) & (sea <= next_edge)] = n
    last_edge = next_edge
plt.imshow(layers)

# %% [markdown]
# Now we can see the variety of layers - with as many colours as our `bins` variable.

# %% [markdown]
# As an aside for later - let's calculate what fraction of the visible sea each layer takes up.

# %%
segment_frequencies = np.bincount(layers[layers >= 0].flatten())
nonzero_pixels = sum(segment_frequencies)
segment_fraction = segment_frequencies / nonzero_pixels
segment_fraction
# Out:
# array([0.10956307, 0.42641286, 0.32271161, 0.10805989, 0.03325258])

# %% [markdown]
# ## Back to charts
#
# Does this match up with our map?

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

layer_bounds = [[53.81683262680313, -6.78096405771856],[55.45928868149063, -5.14400116709356]]

tile = folium.raster_layers.ImageOverlay(
    name='coast',
    image=layers,
    bounds=layer_bounds,
    attr=attr,
    opacity=0.6,
    zindex=1
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

layer_bounds = [[53.81683262680313, -6.78096405771856],[55.45928868149063, -5.14400116709356]]

tile = folium.raster_layers.ImageOverlay(
    name='coast',
    image=layers,
    bounds=layer_bounds,
    attr=attr,
    opacity=0.6,
    zindex=1
).add_to(fmap)

for cluster in clusters.values():
    cluster.add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_276142bb52f1a24d50b1f02b1e2183b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_276142bb52f1a24d50b1f02b1e2183b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_276142bb52f1a24d50b1f02b1e2183b5 = L.map(
#                 &quot;map_276142bb52f1a24d50b1f02b1e2183b5&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ce776ed78b34c2821661296774b941b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_276142bb52f1a24d50b1f02b1e2183b5);
#
#
#             var image_overlay_157ece7c759bd439e428837a1ad99dca = L.imageOverlay(
#                 &quot;data:image/png;base64,...&quot;,
#                 [[53.81683262680313, -6.78096405771856], [55.45928868149063, -5.14400116709356]],
#                 {&quot;attr&quot;: &quot;\n\u003ci\u003e\n\u003ca class=\&quot;a-light\&quot; xmlns:dct=\&quot;http://purl.org/dc/terms/\&quot;\n      href=\&quot;https://s2maps.eu\&quot; property=\&quot;dct:title\&quot;\u003e\n  Sentinel-2 cloudless - https://s2maps.eu\n\u003c/a\u003e by\n\u003ca class=\&quot;a-light\&quot; xmlns:cc=\&quot;http://creativecommons.org/ns#\&quot;\n      href=\&quot;https://eox.at\&quot; property=\&quot;cc:attributionName\&quot;\n      rel=\&quot;cc:attributionURL\&quot;\u003e\n  EOX IT Services GmbH\n\u003c/a\u003e\u003cbr/\u003e\n(Contains modified Copernicus Sentinel data 2016 \u0026amp; 2017)\u003c/i\u003e\n&quot;, &quot;opacity&quot;: 0.6, &quot;zindex&quot;: 1}
#             ).addTo(map_276142bb52f1a24d50b1f02b1e2183b5);
#
#
#             var feature_group_49e185750fe002af442066e1bf380781 = L.featureGroup(
#                 {}
#             ).addTo(map_276142bb52f1a24d50b1f02b1e2183b5);
#
#
#             var marker_9b2ad6f76a6cc5d85e3c64ff67d95f68 = L.marker(
#                 [54.852500423720116, -5.738216765202008],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_e6e5b8b2e3aa5e8bdac59b87f6f64a86 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9b2ad6f76a6cc5d85e3c64ff67d95f68.setIcon(icon_e6e5b8b2e3aa5e8bdac59b87f6f64a86);
#
#
#         var popup_326a69a80162c2537be61a08c68efd98 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3bd888e03377223e9f14c08de2f810c = $(`&lt;div id=&quot;html_b3bd888e03377223e9f14c08de2f810c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ailsa&lt;/div&gt;`)[0];
#                 popup_326a69a80162c2537be61a08c68efd98.setContent(html_b3bd888e03377223e9f14c08de2f810c);
#
#
#
#         marker_9b2ad6f76a6cc5d85e3c64ff67d95f68.bindPopup(popup_326a69a80162c2537be61a08c68efd98)
#         ;
#
#
#
#
#             var marker_e1b92bf1138c5b399a3d11f818d64acf = L.marker(
#                 [54.85368342338922, -5.769783098801826],
#                 {}
#             ).addTo(feature_group_49e185750fe002af442066e1bf380781);
#
#
#             var icon_304bb61703eb1b3beb488f09dd8ee98f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e1b92bf1138c5b399a3d11f818d64acf.setIcon(icon_304bb61703eb1b3beb488f09dd8ee98f);
#
#
#         var popup_731860616beec41f01699cc607ec4615 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_21bb6d191f90c8246f1b9d1b27ac6100 = $(`&lt;div id=&quot;html_21bb6d191f90c8246f1b9d1b27ac6100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Berbice&lt;/div&gt;`)[0];

# %% [markdown]
# Close enough, given all the approximations. Next...
#
# ## Labelling our wrecks
#
# We need to create a function that we can pass a wreck to, and it will give its corresponding layer.
#
# We have a couple of convenient tools in scipy and numpy:
# * linspace : this creates an array linearly spread from one limit to another
# * meshgrid : this turns a set of horizontal and vertical axis ticks into a list of all the points in the corresponding grid
# * inter2p : this takes a series of axis ticks and function values at every grid point, and gives a callable function taking any coordinate whatsoever and returning the linearly-interpolated function value

# %%
import scipy

layer_x = np.linspace(layer_bounds[0][1], layer_bounds[1][1], len(layers[0]))
layer_y = np.linspace(layer_bounds[1][0], layer_bounds[0][0], len(layers))
layers_flat = layers.copy().flatten()
segment = scipy.interpolate.interp2d(layer_x, layer_y, layers)
# Out:
# <ipython-input-66-0f6ad798c1ae>:6: DeprecationWarning: `interp2d` is deprecated!
# `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
# For legacy code, nearly bug-for-bug compatible replacements are
# `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
# scattered 2D data.
#
# In new code, for regular grids use `RegularGridInterpolator` instead.
# For scattered data, prefer `LinearNDInterpolator` or
# `CloughTocher2DInterpolator`.
#
# For more details see
# `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   segment = scipy.interpolate.interp2d(layer_x, layer_y, layers)

# %% [markdown]
# We can plot this interpolated function to see what it looks like in 3D.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

fig = plt.figure(figsize=(10, 10))
# ax = fig.gca(projection='3d')
ax = fig.add_subplot(projection='3d')

ax.set_zlim(-10, 10)
ax.view_init(60, -90)

X, Y = np.meshgrid(layer_x, layer_y)
surf = ax.plot_surface(X, Y, segment(layer_x, layer_y), cmap=cm.coolwarm)
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# <ipython-input-71-6920e8a9a22f>:12: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   surf = ax.plot_surface(X, Y, segment(layer_x, layer_y), cmap=cm.coolwarm)

# %% [markdown]
# Finally, to use our interpolated labelling function, we turn back to our old dataframe method, `apply`.

# %%
def point_to_segment(wreck):
    interp = segment(wreck.geometry.x, wreck.geometry.y)
    wreck['segment'] = int(round(interp[0]))
    return wreck
gdf = gdf.apply(point_to_segment, axis=1)
gdf.head()
# Out:
# Streaming output truncated to the last 5000 lines.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
# ...
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
# <ipython-input-72-8cd22697b703>:2: DeprecationWarning:         `interp2d` is deprecated!
#         `interp2d` is deprecated in SciPy 1.10 and will be removed in SciPy 1.13.0.
#
#         For legacy code, nearly bug-for-bug compatible replacements are
#         `RectBivariateSpline` on regular grids, and `bisplrep`/`bisplev` for
#         scattered 2D data.
#
#         In new code, for regular grids use `RegularGridInterpolator` instead.
#         For scattered data, prefer `LinearNDInterpolator` or
#         `CloughTocher2DInterpolator`.
#
#         For more details see
#         `https://scipy.github.io/devdocs/notebooks/interp_transition_guide.html`
#
#   interp = segment(wreck.geometry.x, wreck.geometry.y)
#                Name   Date_lost                              Type       Cargo  \
# 0             Ailsa  26/02/1892               Steamship (British)     General
# 1  (ex HMS) Alastor  11/03/1946  Corvette / Motor yacht (British)        None
# 2     Albia (poss.)  28/09/1929             Spanish tramp steamer  Copper ore
# 3            Alcedo  ??/01/1892                     Steam coaster        Coal
# 4             Alder        None                              None        None
#
#     Depth   Position_q                                          Condition  \
# 0    1-5m   Reasonable          Badly broken up, part of wreck is onshore
# 1  10-23m     Accurate  Llargely intact with upright funnel. Wooden de...
# 2     10m  Approximate                                  5m high, upright.
# 3      7m  Approximate                         2.5m high, badly broken up
# 4     -3m  Approximate                                               None
#
#               Ref Status               Notes  ... Nation How_lost Legislatio  \
# 0  UKHO, IRW, CMA   LIVE                None  ...   None     None       None
# 1  UKHO, IRW, CMA   LIVE                None  ...   None     None       None
# 2  IRW, UKHO, CMA   LIVE                None  ...   None     None       None
# 3        IRW, CMA   LIVE                None  ...   None     None       None
# 4            UKHO   LIFT  Wreck removed 1938  ...   None     None       None
#
#    Notes_1  Origin  Where_lost                   geometry century label  \
# 0     None    None        None  POINT (-5.73822 54.85250)      19     0
# 1     None    None        None  POINT (-5.62938 54.45155)      20    -1
# 2     None    None        None  POINT (-5.74132 54.94993)      20    -1
# 3     None    None        None  POINT (-5.69620 54.81548)    None    -1
# 4     None    None        None  POINT (-6.09850 54.05322)    None    -1
#
#   segment
# 0      -1
# 1      -1
# 2       2
# 3      -1
# 4      -1
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Displaying this detail

# %% [markdown]
# Lets work out which segments we actually have wrecks in (we don't want to add more layers than necessary)

# %%
segments_active = set(gdf.loc[:, 'segment']) - {-1}
segments_active
# Out:
# {0, 1, 2, 3, 4}

# %% [markdown]
# Now lets create a copy of our dataframe for further manipulation.

# %%
# ldf = gdf.copy()
ldf = gdf[gdf['century'] == '19'].copy()

# %% [markdown]
# Much as above, we can run through our wrecks, but we use a handy colourmap library to give us shades indicating our depth layer.

# %%
import branca.colormap as cm

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

mid = min(segments_active) + (max(segments_active) - min(segments_active)) / 2
colormap = cm.LinearColormap(
    ['red', 'yellow', 'green'],
    index=[min(segments_active), mid, max(segments_active)]
)

def add(wreck):
    pt = wreck.geometry

    if wreck['segment'] > -1:
        colour = colormap(wreck['segment'])
        folium.CircleMarker(
            [pt.y, pt.x],
            popup=wreck['Name'],
            fill_color=colour,
            color=colour
        ).add_to(fmap)

    return wreck

ldf = ldf.apply(add, axis=1)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6981966f4629373e7f972755b8417f61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6981966f4629373e7f972755b8417f61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6981966f4629373e7f972755b8417f61 = L.map(
#                 &quot;map_6981966f4629373e7f972755b8417f61&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c53f34c615422f8c6ec22bda5a2148ef = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6981966f4629373e7f972755b8417f61);
#
#
#             var circle_marker_39e987575bcec14fa8360aa0ecd200c4 = L.circleMarker(
#                 [54.44620042451414, -5.375600094540772],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff7f00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff7f00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6981966f4629373e7f972755b8417f61);
#
#
#         var popup_3e8cf8e057724171150148e08c3a1438 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1a788d48bbf35a9958df8df32b8d49c = $(`&lt;div id=&quot;html_f1a788d48bbf35a9958df8df32b8d49c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archibald Finney&lt;/div&gt;`)[0];
#                 popup_3e8cf8e057724171150148e08c3a1438.setContent(html_f1a788d48bbf35a9958df8df32b8d49c);
#
#
#
#         circle_marker_39e987575bcec14fa8360aa0ecd200c4.bindPopup(popup_3e8cf8e057724171150148e08c3a1438)
#         ;
#
#
#
#
#             var circle_marker_bd9eae6e9a1f6018e8e86b3613919dbe = L.circleMarker(
#                 [55.27499801502037, -6.202576404675912],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6981966f4629373e7f972755b8417f61);
#
#
#         var popup_6b038e05fc1333f8c2eedb55825a8bc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4265a1d8cb271e15cb964eb76bba3633 = $(`&lt;div id=&quot;html_4265a1d8cb271e15cb964eb76bba3633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumberland&lt;/div&gt;`)[0];
#                 popup_6b038e05fc1333f8c2eedb55825a8bc0.setContent(html_4265a1d8cb271e15cb964eb76bba3633);
#
#
#
#         circle_marker_bd9eae6e9a1f6018e8e86b3613919dbe.bindPopup(popup_6b038e05fc1333f8c2eedb55825a8bc0)
#         ;
#
#
#
#
#             var circle_marker_1cb6c894456d4e3e7870a1432d93beb4 = L.circleMarker(
#                 [54.33125416454708, -5.498984966659973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_6981966f4629373e7f972755b8417f61);
#
#
#         var popup_840ae25eaa83fb9d7e2bccd1edc22802 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a33af79e26c28c1abc7483bfbda92377 = $(`&lt;div id=&quot;html_a33af79e26c28c1abc7483bfbda92377&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dunmore&lt;/div&gt;`)[0];
#                 popup_840ae25eaa83fb9d7e2bccd1edc22802.setContent(html_a33af79e26c28c1abc7483bfbda92377);
#
#
#
#         circle_marker_1cb6c894456d4e3e7870a1432d93beb4.bindPopup(popup_840ae25eaa83fb9d7e2bccd1edc22802)
#         ;
#
#
#
#
#             var circle_marker_865e3015cdabafaf8e3af4bb3b962d86 = L.circleMarker(
#                 [55.29536125518683, -6.285922327048246],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;colo

# %% [markdown]
# So that's nice, but it still doesn't answer our question - is there a correlation between depth and wreck frequency? Time to do some stats...

# %%
segment_table = ldf[ldf['segment'] > -1].groupby('segment').agg('count')

total_segmented = segment_table['Name'].sum()

def percentage(row):
    row['Count'] = row['Name']
    row['Blue Depth'] = bin_edges[row.name]
    row['% wrecks'] = 100 * row['Name'] / total_segmented
    row['% area'] = 100 * segment_fraction[row.name]
    row['Wreck Frequency'] = row['% wrecks'] / row['% area']
    return row

segment_table = segment_table.apply(percentage, axis=1)
segment_table = segment_table[['Count', 'Blue Depth', '% wrecks', '% area', 'Wreck Frequency']]
segment_table
# Out:
#          Count  Blue Depth   % wrecks     % area  Wreck Frequency
# segment
# 1          3.0    0.173883  15.789474  42.641286         0.370286
# 2         13.0    0.192912  68.421053  32.271161         2.120192
# 3          3.0    0.211942  15.789474  10.805989         1.461178

# %% [markdown]
# So not hugely, but around a third higher for the shallow (mostly coastal) areas. Not a huge gap, but oh well... it may be worth trying for other centuries though...

# %% [markdown]
# In any case, let's put it all together and see what our shipwreck map now looks like.

# %%
fmap = folium.Map(location=(middle.y, middle.x), zoom_start=7)

def add(wreck):
    pt = wreck.geometry

    if wreck['segment'] > -1:
        colour = colormap(wreck['segment'])
        folium.CircleMarker(
            [pt.y, pt.x],
            popup="%s (%.2lf, %.2lf)" % (wreck['Name'], wreck.geometry.y, wreck.geometry.x),
            fill_color=colour,
            fill_opacity=1,
            radius=8,
            color=colour
        ).add_to(fmap)

    return wreck

ldf.apply(add, axis=1)

tile = folium.raster_layers.ImageOverlay(
    name='coast',
    image=layers,
    bounds=layer_bounds,
    attr=attr,
    opacity=0.9,
    zindex=1
).add_to(fmap)

LayerControl().add_to(fmap)
fmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a28ee2f34da43476c471b50bc3c64ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a28ee2f34da43476c471b50bc3c64ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a28ee2f34da43476c471b50bc3c64ee = L.map(
#                 &quot;map_9a28ee2f34da43476c471b50bc3c64ee&quot;,
#                 {
#                     center: [54.64427445282978, -5.824818665830236],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9230988eb9b813a1323e826e4b094a79 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a28ee2f34da43476c471b50bc3c64ee);
#
#
#             var circle_marker_fce1afd88f0c5ccc7cf98f63ca4c4ecb = L.circleMarker(
#                 [54.44620042451414, -5.375600094540772],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff7f00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff7f00ff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a28ee2f34da43476c471b50bc3c64ee);
#
#
#         var popup_4fb6041959a6e01bf563c9a356f9fda2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9acc6ec58a6e9b20b3df8513a4c55fa9 = $(`&lt;div id=&quot;html_9acc6ec58a6e9b20b3df8513a4c55fa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Archibald Finney (54.45, -5.38)&lt;/div&gt;`)[0];
#                 popup_4fb6041959a6e01bf563c9a356f9fda2.setContent(html_9acc6ec58a6e9b20b3df8513a4c55fa9);
#
#
#
#         circle_marker_fce1afd88f0c5ccc7cf98f63ca4c4ecb.bindPopup(popup_4fb6041959a6e01bf563c9a356f9fda2)
#         ;
#
#
#
#
#             var circle_marker_8a974f827be8e800162d1fd477879f5b = L.circleMarker(
#                 [55.27499801502037, -6.202576404675912],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a28ee2f34da43476c471b50bc3c64ee);
#
#
#         var popup_70128ae6e37a6e0824d09df96885dbf1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04914d448c682cdab9fa1e41286da56c = $(`&lt;div id=&quot;html_04914d448c682cdab9fa1e41286da56c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cumberland (55.27, -6.20)&lt;/div&gt;`)[0];
#                 popup_70128ae6e37a6e0824d09df96885dbf1.setContent(html_04914d448c682cdab9fa1e41286da56c);
#
#
#
#         circle_marker_8a974f827be8e800162d1fd477879f5b.bindPopup(popup_70128ae6e37a6e0824d09df96885dbf1)
#         ;
#
#
#
#
#             var circle_marker_d51dabeefc92ad4fc161be4cac1567c2 = L.circleMarker(
#                 [54.33125416454708, -5.498984966659973],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ffff00ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ffff00ff&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 8, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a28ee2f34da43476c471b50bc3c64ee);
#
#
#         var popup_0878f515fc2e9cdddcb41882408c63de = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5f158b69476e1d0

# %% [markdown]
# # Exercise

# %% [markdown]
# Try rerunning the above for different centuries. Do all centuries (with data) have similar results? Does this tell you something about seafaring over time? Are all century datasets equally valid for analysis?

# %% [markdown]
# # Answers

# %%
import dateutil

def get_century(dt):
    date = None

    if dt:
        try:
            date = dateutil.parser.parse(dt)
        except ValueError:
            pass
        else:
            if date and date.year:
                date = str(date.year)[0:2]
            else:
                date = None

    return date
